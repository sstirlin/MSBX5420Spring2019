# %% [markdown]
# # CitiBike exploration
#
# We want to explore the streaming dataset published by CitiBike (a NYC-based bike-share company).
#
# They publish their data using a REST endpoint.
#
# Let's hit their endpoint to explore it a little bit:

# %%
import requests

r = requests.get("http://gbfs.citibikenyc.com/gbfs/gbfs.json")

# %% [markdown]
# We always need to check the status code.  `200` indicates success.  If we do not succeed then we should probably figure out some "retry" logic:

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# The content is just bytes.  In python bytes "look" like a string, but they have a `b` in front.  Like this:
# ```
# b'thesearebytesnotastring'
# ```

# %%
r.content
# Out:
# b'{"last_updated":1554069608,"ttl":10,"data":{"en":{"feeds":[{"name":"station_status","url":"https://gbfs.citibikenyc.com/gbfs/en/station_status.json"},{"name":"system_regions","url":"https://gbfs.citibikenyc.com/gbfs/en/system_regions.json"},{"name":"station_information","url":"https://gbfs.citibikenyc.com/gbfs/en/station_information.json"},{"name":"system_alerts","url":"https://gbfs.citibikenyc.com/gbfs/en/system_alerts.json"},{"name":"system_information","url":"https://gbfs.citibikenyc.com/gbfs/en/system_information.json"}]},"es":{"feeds":[{"name":"station_status","url":"https://gbfs.citibikenyc.com/gbfs/es/station_status.json"},{"name":"system_regions","url":"https://gbfs.citibikenyc.com/gbfs/es/system_regions.json"},{"name":"station_information","url":"https://gbfs.citibikenyc.com/gbfs/es/station_information.json"},{"name":"system_alerts","url":"https://gbfs.citibikenyc.com/gbfs/es/system_alerts.json"},{"name":"system_information","url":"https://gbfs.citibikenyc.com/gbfs/es/system_information.json"}]},"fr":{"feeds":[{"name":"station_status","url":"https://gbfs.citibikenyc.com/gbfs/fr/station_status.json"},{"name":"system_regions","url":"https://gbfs.citibikenyc.com/gbfs/fr/system_regions.json"},{"name":"station_information","url":"https://gbfs.citibikenyc.com/gbfs/fr/station_information.json"},{"name":"system_alerts","url":"https://gbfs.citibikenyc.com/gbfs/fr/system_alerts.json"},{"name":"system_information","url":"https://gbfs.citibikenyc.com/gbfs/fr/system_information.json"}]}}}'

# %% [markdown]
# This looks like json, which is a VERY common way to transmit information over HTTP.
#
# However, we first need to convert these bytes to a string.  Recall that in python strings are *unicode*.  To decode bytes -> unicode we need to know how it was encoded in the first place.  Most of the time you will encounter the `utf-8` encoding.  Let's try it:

# %%
msg = r.content.decode('utf-8')
msg
# Out:
# '{"last_updated":1554069608,"ttl":10,"data":{"en":{"feeds":[{"name":"station_status","url":"https://gbfs.citibikenyc.com/gbfs/en/station_status.json"},{"name":"system_regions","url":"https://gbfs.citibikenyc.com/gbfs/en/system_regions.json"},{"name":"station_information","url":"https://gbfs.citibikenyc.com/gbfs/en/station_information.json"},{"name":"system_alerts","url":"https://gbfs.citibikenyc.com/gbfs/en/system_alerts.json"},{"name":"system_information","url":"https://gbfs.citibikenyc.com/gbfs/en/system_information.json"}]},"es":{"feeds":[{"name":"station_status","url":"https://gbfs.citibikenyc.com/gbfs/es/station_status.json"},{"name":"system_regions","url":"https://gbfs.citibikenyc.com/gbfs/es/system_regions.json"},{"name":"station_information","url":"https://gbfs.citibikenyc.com/gbfs/es/station_information.json"},{"name":"system_alerts","url":"https://gbfs.citibikenyc.com/gbfs/es/system_alerts.json"},{"name":"system_information","url":"https://gbfs.citibikenyc.com/gbfs/es/system_information.json"}]},"fr":{"feeds":[{"name":"station_status","url":"https://gbfs.citibikenyc.com/gbfs/fr/station_status.json"},{"name":"system_regions","url":"https://gbfs.citibikenyc.com/gbfs/fr/system_regions.json"},{"name":"station_information","url":"https://gbfs.citibikenyc.com/gbfs/fr/station_information.json"},{"name":"system_alerts","url":"https://gbfs.citibikenyc.com/gbfs/fr/system_alerts.json"},{"name":"system_information","url":"https://gbfs.citibikenyc.com/gbfs/fr/system_information.json"}]}}}'

# %% [markdown]
# That worked.  Indeed those bytes were in `utf-8`.  Now we have an honest string (that contains json) and we can deserialize it into a python dict:

# %%
import ujson

data = ujson.loads(msg)
data
# Out:
# {'last_updated': 1554069608,
#  'ttl': 10,
#  'data': {'en': {'feeds': [{'name': 'station_status',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/en/station_status.json'},
#     {'name': 'system_regions',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/en/system_regions.json'},
#     {'name': 'station_information',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/en/station_information.json'},
#     {'name': 'system_alerts',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/en/system_alerts.json'},
#     {'name': 'system_information',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/en/system_information.json'}]},
#   'es': {'feeds': [{'name': 'station_status',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/es/station_status.json'},
#     {'name': 'system_regions',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/es/system_regions.json'},
#     {'name': 'station_information',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/es/station_information.json'},
#     {'name': 'system_alerts',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/es/system_alerts.json'},
#     {'name': 'system_information',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/es/system_information.json'}]},
#   'fr': {'feeds': [{'name': 'station_status',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/fr/station_status.json'},
#     {'name': 'system_regions',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/fr/system_regions.json'},
#     {'name': 'station_information',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/fr/station_information.json'},
#     {'name': 'system_alerts',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/fr/system_alerts.json'},
#     {'name': 'system_information',
#      'url': 'https://gbfs.citibikenyc.com/gbfs/fr/system_information.json'}]}}}

# %%
data.keys()
# Out:
# dict_keys(['last_updated', 'ttl', 'data'])

# %%
data['last_updated']
# Out:
# 1554069608

# %% [markdown]
# That is a unix timestamp.  Now let's look at the `ttl` (time to live):

# %%
data['ttl']
# Out:
# 10

# %% [markdown]
# Apparently this just shows us more REST endpoints where we can get the actual data:

# %%
data['data']['en']['feeds']
# Out:
# [{'name': 'station_status',
#   'url': 'https://gbfs.citibikenyc.com/gbfs/en/station_status.json'},
#  {'name': 'system_regions',
#   'url': 'https://gbfs.citibikenyc.com/gbfs/en/system_regions.json'},
#  {'name': 'station_information',
#   'url': 'https://gbfs.citibikenyc.com/gbfs/en/station_information.json'},
#  {'name': 'system_alerts',
#   'url': 'https://gbfs.citibikenyc.com/gbfs/en/system_alerts.json'},
#  {'name': 'system_information',
#   'url': 'https://gbfs.citibikenyc.com/gbfs/en/system_information.json'}]

# %% [markdown]
# We are mostly interested in `station_status` and `station_information`.  Let's hit `station_status`:

# %% [markdown]
# ## Station Information and Status

# %%
r = requests.get('https://gbfs.citibikenyc.com/gbfs/en/station_information.json')
r.status_code
# Out:
# 200

# %%
station_info = ujson.loads(r.content.decode('utf-8'))
station_info
# Out:
# {'last_updated': 1554070800,
#  'ttl': 10,
#  'data': {'stations': [{'station_id': '72',
#     'external_id': '66db237e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 52 St & 11 Ave',
#     'short_name': '6926.01',
#     'lat': 40.76727216,
#     'lon': -73.99392888,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 55,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=72',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '79',
#     'external_id': '66db269c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Franklin St & W Broadway',
#     'short_name': '5430.08',
#     'lat': 40.71911552,
#     'lon': -74.00666661,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=79',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '82',
#     'external_id': '66db277a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'St James Pl & Pearl St',
#     'short_name': '5167.06',
#     'lat': 40.71117416,
#     'lon': -74.00016545,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=82',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '83',
#     'external_id': '66db281e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Atlantic Ave & Fort Greene Pl',
#     'short_name': '4354.07',
#     'lat': 40.68382604,
#     'lon': -73.97632328,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 62,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=83',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '119',
#     'external_id': '66db2953-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Park Ave & St Edwards St',
#     'short_name': '4700.06',
#     'lat': 40.69608941,
#     'lon': -73.97803415,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=119',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '120',
#     'external_id': '66db29e6-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lexington Ave & Classon Ave',
#     'short_name': '4452.03',
#     'lat': 40.68676793,
#     'lon': -73.95928168,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=120',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '127',
#     'external_id': '66db2a71-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Barrow St & Hudson St',
#     'short_name': '5805.05',
#     'lat': 40.73172428,
#     'lon': -74.00674436,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=127',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '128',
#     'external_id': '66db2afe-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'MacDougal St & Prince St',
#     'short_name': '5687.04',
#     'lat': 40.72710258,
#     'lon': -74.00297088,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=128',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '143',
#     'external_id': '66db2d2b-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Clinton St & Joralemon St',
#     'short_name': '4605.04',
#     'lat': 40.69239502,
#     'lon': -73.99337909,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 24,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=143',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '144',
#     'external_id': '66db2db5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Nassau St & Navy St',
#     'short_name': '4812.02',
#     'lat': 40.69839895,
#     'lon': -73.98068914,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=144',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '146',
#     'external_id': '66db2e3a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Hudson St & Reade St',
#     'short_name': '5359.10',
#     'lat': 40.71625008,
#     'lon': -74.0091059,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=146',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '150',
#     'external_id': '66db2f4c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 2 St & Avenue C',
#     'short_name': '5476.03',
#     'lat': 40.7208736,
#     'lon': -73.98085795,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 54,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=150',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '151',
#     'external_id': '66db2fd0-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Cleveland Pl & Spring St',
#     'short_name': '5492.05',
#     'lat': 40.722103786686034,
#     'lon': -73.99724900722504,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=151',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '157',
#     'external_id': '66db316a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Henry St & Atlantic Ave',
#     'short_name': '4531.05',
#     'lat': 40.69089272,
#     'lon': -73.99612349,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=157',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '161',
#     'external_id': '66db3273-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'LaGuardia Pl & W 3 St',
#     'short_name': '5721.14',
#     'lat': 40.72917025,
#     'lon': -73.99810231,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=161',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '164',
#     'external_id': '66db32fb-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 47 St & 2 Ave',
#     'short_name': '6498.10',
#     'lat': 40.75323098,
#     'lon': -73.97032517,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 47,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=164',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '167',
#     'external_id': '66db337f-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 39 St & 3 Ave',
#     'short_name': '6389.03',
#     'lat': 40.7489006,
#     'lon': -73.97604882,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 45,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=167',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '168',
#     'external_id': '66db33fc-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 18 St & 6 Ave',
#     'short_name': '6064.08',
#     'lat': 40.73971301,
#     'lon': -73.99456405,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 47,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=168',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '173',
#     'external_id': '66db347b-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broadway & W 49 St',
#     'short_name': '6708.02',
#     'lat': 40.76068327096592,
#     'lon': -73.9845272898674,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 51,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=173',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '174',
#     'external_id': '66db34fc-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 25 St & 1 Ave',
#     'short_name': '6004.07',
#     'lat': 40.7381765,
#     'lon': -73.97738662,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=174',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '195',
#     'external_id': '66db3583-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Liberty St & Broadway',
#     'short_name': '5105.01',
#     'lat': 40.70905623,
#     'lon': -74.01043382,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 45,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=195',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '212',
#     'external_id': '66db3606-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 16 St & The High Line',
#     'short_name': '6233.05',
#     'lat': 40.74334935,
#     'lon': -74.00681753,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 60,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=212',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '216',
#     'external_id': '66db3687-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Columbia Heights & Cranberry St',
#     'short_name': '4829.01',
#     'lat': 40.70037867,
#     'lon': -73.99548059,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=216',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '217',
#     'external_id': '66db3708-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Old Fulton St',
#     'short_name': '4903.08',
#     'lat': 40.70277159,
#     'lon': -73.99383605,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=217',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '223',
#     'external_id': '66db3816-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 13 St & 7 Ave',
#     'short_name': '6030.04',
#     'lat': 40.73781509,
#     'lon': -73.99994661,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=223',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '224',
#     'external_id': '66db3898-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Spruce St & Nassau St',
#     'short_name': '5137.10',
#     'lat': 40.71146364,
#     'lon': -74.00552427,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=224',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '228',
#     'external_id': '66db3997-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 48 St & 3 Ave',
#     'short_name': '6541.03',
#     'lat': 40.7546011026,
#     'lon': -73.971878855,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 55,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=228',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '229',
#     'external_id': '66db3a1e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Great Jones St',
#     'short_name': '5636.11',
#     'lat': 40.72743423,
#     'lon': -73.99379025,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=229',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '236',
#     'external_id': '66db3ba0-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'St Marks Pl & 2 Ave',
#     'short_name': '5669.10',
#     'lat': 40.7284186,
#     'lon': -73.98713956,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 47,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=236',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '237',
#     'external_id': '66db3c29-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 11 St & 2 Ave',
#     'short_name': '5746.04',
#     'lat': 40.73047309,
#     'lon': -73.98672378,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=237',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '238',
#     'external_id': '66db3cab-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Bank St & Washington St',
#     'short_name': '5964.01',
#     'lat': 40.7361967,
#     'lon': -74.00859207,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=238',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '239',
#     'external_id': '66db3d2a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Willoughby St & Fleet St',
#     'short_name': '4628.05',
#     'lat': 40.69196566,
#     'lon': -73.9813018,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=239',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '241',
#     'external_id': '66db3da9-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'DeKalb Ave & S Portland Ave',
#     'short_name': '4546.04',
#     'lat': 40.68981035,
#     'lon': -73.97493121,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=241',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '242',
#     'external_id': '66db3e32-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Carlton Ave & Flushing Ave',
#     'short_name': '4732.08',
#     'lat': 40.697787,
#     'lon': -73.973736,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=242',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '243',
#     'external_id': '66db3e9d-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Fulton St & Rockwell Pl',
#     'short_name': '4513.03',
#     'lat': 40.688226,
#     'lon': -73.979382,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=243',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '244',
#     'external_id': '66db3f01-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Willoughby Ave & Hall St',
#     'short_name': '4611.03',
#     'lat': 40.69196035,
#     'lon': -73.96536851,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=244',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '245',
#     'external_id': '66db3f62-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Myrtle Ave & St Edwards St',
#     'short_name': '4659.02',
#     'lat': 40.69327018,
#     'lon': -73.97703874,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=245',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '247',
#     'external_id': '66db3fc9-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Perry St & Bleecker St',
#     'short_name': '5922.07',
#     'lat': 40.73535398,
#     'lon': -74.00483091,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 0,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=247',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '248',
#     'external_id': '66db402c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Laight St & Hudson St',
#     'short_name': '5539.06',
#     'lat': 40.72185379,
#     'lon': -74.00771779,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=248',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '249',
#     'external_id': '66db408f-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Harrison St & Hudson St',
#     'short_name': '5400.05',
#     'lat': 40.71870987,
#     'lon': -74.0090009,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=249',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '251',
#     'external_id': '66db4158-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Mott St & Prince St',
#     'short_name': '5561.04',
#     'lat': 40.72317958,
#     'lon': -73.99480012,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=251',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '252',
#     'external_id': '66db41bf-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'MacDougal St & Washington Sq',
#     'short_name': '5797.01',
#     'lat': 40.73226398,
#     'lon': -73.99852205,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=252',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '254',
#     'external_id': '66db4282-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 11 St & 6 Ave',
#     'short_name': '5914.03',
#     'lat': 40.73532427,
#     'lon': -73.99800419,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 59,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=254',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '257',
#     'external_id': '66db4351-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lispenard St & Broadway',
#     'short_name': '5391.06',
#     'lat': 40.71939226,
#     'lon': -74.00247214,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=257',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '258',
#     'external_id': '66db43b5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'DeKalb Ave & Vanderbilt Ave',
#     'short_name': '4461.04',
#     'lat': 40.68940747,
#     'lon': -73.96885458,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=258',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '259',
#     'external_id': '66db4417-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'South St & Whitehall St',
#     'short_name': '4846.01',
#     'lat': 40.70122128,
#     'lon': -74.01234218,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=259',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '260',
#     'external_id': '66db447a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broad St & Bridge St',
#     'short_name': '4962.08',
#     'lat': 40.70365182,
#     'lon': -74.01167797,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=260',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '261',
#     'external_id': '66db44e5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Johnson St & Gold St',
#     'short_name': '4668.08',
#     'lat': 40.69474881,
#     'lon': -73.98362464,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=261',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '262',
#     'external_id': '66db4549-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Washington Park',
#     'short_name': '4546.05',
#     'lat': 40.6917823,
#     'lon': -73.9737299,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 24,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=262',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '264',
#     'external_id': '66db460d-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Maiden Ln & Pearl St',
#     'short_name': '5065.10',
#     'lat': 40.70706456,
#     'lon': -74.00731853,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=264',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '265',
#     'external_id': '66db4671-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Stanton St & Chrystie St',
#     'short_name': '5523.02',
#     'lat': 40.72229346,
#     'lon': -73.99147535,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=265',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '266',
#     'external_id': '66db46d7-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Avenue D & E 8 St',
#     'short_name': '5506.10',
#     'lat': 40.72368361,
#     'lon': -73.97574813,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=266',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '267',
#     'external_id': '66db473c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broadway & W 36 St',
#     'short_name': '6441.01',
#     'lat': 40.75097711,
#     'lon': -73.98765428,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 57,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=267',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '268',
#     'external_id': '66db479e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Howard St & Centre St',
#     'short_name': '5422.04',
#     'lat': 40.71910537,
#     'lon': -73.99973337,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=268',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '270',
#     'external_id': '66db5c14-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Adelphi St & Myrtle Ave',
#     'short_name': '4620.02',
#     'lat': 40.69308257,
#     'lon': -73.97178913,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=270',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '274',
#     'external_id': '66db5d28-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lafayette Ave & Fort Greene Pl',
#     'short_name': '4395.04',
#     'lat': 40.68691865,
#     'lon': -73.976682,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=274',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '275',
#     'external_id': '66db5d92-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Washington Ave & Greene Ave',
#     'short_name': '4419.03',
#     'lat': 40.68650065,
#     'lon': -73.96563307,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=275',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '276',
#     'external_id': '66db5dfb-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Duane St & Greenwich St',
#     'short_name': '5400.08',
#     'lat': 40.71748752,
#     'lon': -74.0104554,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 25,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=276',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '278',
#     'external_id': '66db5e6a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Concord St & Bridge St',
#     'short_name': '4781.03',
#     'lat': 40.69766564,
#     'lon': -73.98476437,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=278',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '279',
#     'external_id': '66db5ed3-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Peck Slip & Front St',
#     'short_name': '5098.10',
#     'lat': 40.707873,
#     'lon': -74.00167,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 36,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=279',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '280',
#     'external_id': '66db5f40-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 10 St & 5 Ave',
#     'short_name': '5872.08',
#     'lat': 40.73331967,
#     'lon': -73.99510132,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=280',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '281',
#     'external_id': '66db5fae-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Grand Army Plaza & Central Park S',
#     'short_name': '6839.10',
#     'lat': 40.7643971,
#     'lon': -73.97371465,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 66,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=281',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '282',
#     'external_id': '66db6299-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Kent Ave & S 11 St',
#     'short_name': '5062.01',
#     'lat': 40.707644944175705,
#     'lon': -73.96841526031494,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=282',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '285',
#     'external_id': '66db6387-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broadway & E 14 St',
#     'short_name': '5905.12',
#     'lat': 40.73454567,
#     'lon': -73.99074142,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 53,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=285',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '289',
#     'external_id': '66db63f4-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Monroe St & Classon Ave',
#     'short_name': '4336.01',
#     'lat': 40.6845683,
#     'lon': -73.95881081,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=289',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '291',
#     'external_id': '66db64d1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Madison St & Montgomery St',
#     'short_name': '5262.09',
#     'lat': 40.713126,
#     'lon': -73.984844,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 20,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=291',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '293',
#     'external_id': '66db65aa-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lafayette St & E 8 St',
#     'short_name': '5788.13',
#     'lat': 40.73020660529954,
#     'lon': -73.99102628231049,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 55,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=293',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '295',
#     'external_id': '66db6889-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Pike St & E Broadway',
#     'short_name': '5270.05',
#     'lat': 40.71406667,
#     'lon': -73.99293911,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 24,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=295',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '296',
#     'external_id': '66db68fc-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Division St & Bowery',
#     'short_name': '5238.04',
#     'lat': 40.71413089,
#     'lon': -73.9970468,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=296',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '297',
#     'external_id': '66db6963-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 15 St & 3 Ave',
#     'short_name': '5863.07',
#     'lat': 40.734232,
#     'lon': -73.986923,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=297',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '298',
#     'external_id': '66db69d0-0aca-11e7-82f6-3863bb44ef7c',
#     'name': '3 Ave & Schermerhorn St',
#     'short_name': '4437.01',
#     'lat': 40.68683208,
#     'lon': -73.9796772,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=298',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '301',
#     'external_id': '66db6aae-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 2 St & Avenue B',
#     'short_name': '5515.02',
#     'lat': 40.72217444,
#     'lon': -73.98368779,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 58,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=301',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '302',
#     'external_id': '66db6cd4-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Avenue D & E 3 St',
#     'short_name': '5436.09',
#     'lat': 40.72082834,
#     'lon': -73.97793172,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=302',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '303',
#     'external_id': '66db6d40-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Mercer St & Spring St',
#     'short_name': '5532.01',
#     'lat': 40.72362738,
#     'lon': -73.99949601,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 67,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=303',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '304',
#     'external_id': '66db6da2-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broadway & Battery Pl',
#     'short_name': '4962.01',
#     'lat': 40.70463334,
#     'lon': -74.01361706,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=304',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '305',
#     'external_id': '66db6e49-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 58 St & 3 Ave',
#     'short_name': '6762.02',
#     'lat': 40.76095756,
#     'lon': -73.96724467,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=305',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '307',
#     'external_id': '66db6f2e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Canal St & Rutgers St',
#     'short_name': '5303.08',
#     'lat': 40.71427487,
#     'lon': -73.98990025,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=307',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '308',
#     'external_id': '66db7152-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'St James Pl & Oliver St',
#     'short_name': '5238.05',
#     'lat': 40.71307916,
#     'lon': -73.99851193,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=308',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '309',
#     'external_id': '66db71be-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Murray St & West St',
#     'short_name': '5329.06',
#     'lat': 40.7149787,
#     'lon': -74.013012,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 41,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=309',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '310',
#     'external_id': '66db7221-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'State St & Smith St',
#     'short_name': '4565.06',
#     'lat': 40.68926942,
#     'lon': -73.98912867,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 36,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=310',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '311',
#     'external_id': '66db728c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Norfolk St & Broome St',
#     'short_name': '5374.01',
#     'lat': 40.7172274,
#     'lon': -73.98802084,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=311',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '312',
#     'external_id': '66db72f1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Allen St & Stanton St',
#     'short_name': '5484.09',
#     'lat': 40.722055,
#     'lon': -73.989111,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=312',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '313',
#     'external_id': '66db74a5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Washington Ave & Park Ave',
#     'short_name': '4724.03',
#     'lat': 40.69610226,
#     'lon': -73.96751037,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=313',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '314',
#     'external_id': '66db7551-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Cadman Plaza West & Montague St',
#     'short_name': '4677.07',
#     'lat': 40.69383,
#     'lon': -73.990539,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=314',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '315',
#     'external_id': '66db75cc-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'South St & Gouverneur Ln',
#     'short_name': '4953.04',
#     'lat': 40.70355377,
#     'lon': -74.00670227,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 29,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=315',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '316',
#     'external_id': '66db7637-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Fulton St & William St',
#     'short_name': '5137.11',
#     'lat': 40.70955958,
#     'lon': -74.00653609,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 43,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=316',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '317',
#     'external_id': '66db76a1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 6 St & Avenue B',
#     'short_name': '5584.04',
#     'lat': 40.72453734,
#     'lon': -73.98185424,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 54,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=317',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '319',
#     'external_id': '66db79a3-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Fulton St & Broadway',
#     'short_name': '5175.08',
#     'lat': 40.711066,
#     'lon': -74.009447,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=319',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '320',
#     'external_id': '66db7a0d-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Leonard St & Church St',
#     'short_name': '5359.11',
#     'lat': 40.717571,
#     'lon': -74.005549,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=320',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '321',
#     'external_id': '66db7a71-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Cadman Plaza E & Red Cross Pl',
#     'short_name': '4821.06',
#     'lat': 40.69991755,
#     'lon': -73.98971773,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=321',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '322',
#     'external_id': '66db87e3-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Clinton St & Tillary St',
#     'short_name': '4748.04',
#     'lat': 40.696191999999996,
#     'lon': -73.991218,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=322',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': False},
#    {'station_id': '323',
#     'external_id': '66db88f5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lawrence St & Willoughby St',
#     'short_name': '4596.09',
#     'lat': 40.69236178,
#     'lon': -73.98631746,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=323',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '324',
#     'external_id': '66db89a3-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'DeKalb Ave & Hudson Ave',
#     'short_name': '4513.06',
#     'lat': 40.689888,
#     'lon': -73.981013,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 51,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=324',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '325',
#     'external_id': '66db8c10-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 19 St & 3 Ave',
#     'short_name': '5938.01',
#     'lat': 40.73624527,
#     'lon': -73.98473765,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=325',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '326',
#     'external_id': '66db8ca4-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 11 St & 1 Ave',
#     'short_name': '5746.14',
#     'lat': 40.72953837,
#     'lon': -73.98426726,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 41,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=326',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '327',
#     'external_id': '66db8d89-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Vesey Pl & River Terrace',
#     'short_name': '5297.02',
#     'lat': 40.7153379,
#     'lon': -74.01658354,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=327',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '328',
#     'external_id': '66db8fde-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Watts St & Greenwich St',
#     'short_name': '5578.02',
#     'lat': 40.72405549,
#     'lon': -74.00965965,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=328',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '330',
#     'external_id': '66db90f1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Reade St & Broadway',
#     'short_name': '5247.10',
#     'lat': 40.71450451,
#     'lon': -74.00562789,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=330',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '331',
#     'external_id': '66db930d-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Pike St & Monroe St',
#     'short_name': '5159.04',
#     'lat': 40.71173107,
#     'lon': -73.99193043,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=331',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '332',
#     'external_id': '66db93a1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Cherry St',
#     'short_name': '5181.04',
#     'lat': 40.71219906,
#     'lon': -73.97948148,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 36,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=332',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '334',
#     'external_id': '66db95e5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 20 St & 7 Ave',
#     'short_name': '6182.02',
#     'lat': 40.74238787,
#     'lon': -73.99726235,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=334',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '335',
#     'external_id': '66db9675-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Washington Pl & Broadway',
#     'short_name': '5755.01',
#     'lat': 40.72903917,
#     'lon': -73.99404649,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
# ...
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3690',
#     'external_id': '18fcd2c1-dc8b-4a52-9f18-e9b9003bbea5',
#     'name': 'Park Pl & Church St',
#     'short_name': '5288.08',
#     'lat': 40.71334184275907,
#     'lon': -74.00935515761375,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 36,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3690',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3691',
#     'external_id': '00284700-9d22-42ce-8485-113fed9879c1',
#     'name': '28 Ave & 44 St',
#     'short_name': '6879.04',
#     'lat': 40.76408932350688,
#     'lon': -73.91065120697021,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3691',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3692',
#     'external_id': '918af7b2-e05c-477a-a8c0-7dcff984c566',
#     'name': '5 St & Market St',
#     'short_name': '4843.01',
#     'lat': 40.699997484388504,
#     'lon': -73.97440128028393,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 15,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3692',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3693',
#     'external_id': '0e3dedfb-df10-4900-a67b-95349a81bc5c',
#     'name': 'N 11 St & Kent Ave',
#     'short_name': '5489.04',
#     'lat': 40.72248188638219,
#     'lon': -73.95921930670738,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3693',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3694',
#     'external_id': '1ec24ce3-2b69-4f3a-a153-c73e583d11f3',
#     'name': 'Jackson Square',
#     'short_name': 'JC105',
#     'lat': 40.71113,
#     'lon': -74.0789,
#     'region_id': 70,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 18,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3694',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3697',
#     'external_id': 'b0cc08dc-e7dd-48d1-8901-ba496f3ff2f5',
#     'name': 'W 64 St & Thelonious Monk Circle',
#     'short_name': '7123.04',
#     'lat': 40.77515953434235,
#     'lon': -73.98918695747852,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 43,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3697',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3699',
#     'external_id': 'b442a648-e9f4-4893-951a-64d258bc0e55',
#     'name': 'W 50 St & 9 Ave',
#     'short_name': '6854.05',
#     'lat': 40.763604677958625,
#     'lon': -73.98917958140373,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3699',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3701',
#     'external_id': '80b76a71-cc5d-4bb9-93cd-913784617701',
#     'name': 'Cliff St & Fulton St',
#     'short_name': '5065.11',
#     'lat': 40.70831794366396,
#     'lon': -74.00504082441329,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 37,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3701',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3704',
#     'external_id': 'c72970e7-7f1a-4671-bf55-fc34be7c9413',
#     'name': '47 Ave & Skillman Ave',
#     'short_name': '6237.01',
#     'lat': 40.7437524099784,
#     'lon': -73.94176483154297,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3704',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3707',
#     'external_id': '454b4a83-d0b1-42a2-8163-261e2a9d6ab9',
#     'name': 'Lexington Ave & E 26 St',
#     'short_name': '6089.08',
#     'lat': 40.741459,
#     'lon': -73.983293,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 55,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3707',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3708',
#     'external_id': 'eafa19ed-88c2-4efc-bd73-3961f85b6063',
#     'name': 'W 13 St & 5 Ave',
#     'short_name': '5947.04',
#     'lat': 40.735445,
#     'lon': -73.99431,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 29,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3708',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3709',
#     'external_id': '09dfc0e3-a448-477c-bb3c-9467dc51ef8d',
#     'name': 'W 15 St & 6 Ave',
#     'short_name': '5989.02',
#     'lat': 40.738046142482766,
#     'lon': -73.99642959237099,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 51,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3709',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3711',
#     'external_id': 'd9160982-2d9b-4f08-9469-a559a7b62809',
#     'name': 'E 13 St & Avenue A',
#     'short_name': '5779.09',
#     'lat': 40.72966729392978,
#     'lon': -73.98067966103554,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 47,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3711',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3712',
#     'external_id': 'a47f77a2-9008-4652-a4f1-b95eee723a1b',
#     'name': 'W 35 St & Dyer Ave',
#     'short_name': '6569.08',
#     'lat': 40.754691750226016,
#     'lon': -73.99740189313889,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 41,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3712',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3714',
#     'external_id': 'e58234a3-5b23-427e-948f-c1e4571b2bfa',
#     'name': 'Division Av & Hooper St',
#     'short_name': '5045.05',
#     'lat': 40.70684203101325,
#     'lon': -73.9544353965357,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 61,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3714',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3715',
#     'external_id': '1b28836b-29fd-47a7-9a98-44cd792918fb',
#     'name': 'Driggs Ave & N 9 St',
#     'short_name': '5411.08',
#     'lat': 40.71816969454208,
#     'lon': -73.95520135760307,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3715',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3716',
#     'external_id': 'c36cfa58-29fe-4c0c-a14f-41c3463487fd',
#     'name': '40 Ave & Crescent St',
#     'short_name': '6462.05',
#     'lat': 40.753599202005596,
#     'lon': -73.93795609474182,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3716',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3718',
#     'external_id': '99d149f9-ad40-461e-beea-fcbf086f9b5a',
#     'name': 'E 11 St & Avenue B',
#     'short_name': '5659.11',
#     'lat': 40.72746420692392,
#     'lon': -73.97950418293476,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 46,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3718',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3720',
#     'external_id': '8ea59fa2-6f09-4dac-b27d-abfa5ee15ccf',
#     'name': 'Wyckoff St & Bond St',
#     'short_name': '4330.08',
#     'lat': 40.68461653897949,
#     'lon': -73.98721285164356,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3720',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3721',
#     'external_id': 'cae4f2f4-9642-474c-95cc-6cc07592f120',
#     'name': '31 St & Newtown Ave',
#     'short_name': '6923.20',
#     'lat': 40.7675487799971,
#     'lon': -73.9209334552288,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 34,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3721',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3723',
#     'external_id': '25d256fe-15a7-4d97-ad27-56885e7c0491',
#     'name': 'Cadman Plaza E & Johnson St',
#     'short_name': '4677.10',
#     'lat': 40.695317277669034,
#     'lon': -73.99015724658966,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3723',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '3724',
#     'external_id': 'b94cc90e-9ca2-4471-8371-23be051e0157',
#     'name': '7 Ave & Central Park South',
#     'short_name': '6912.01',
#     'lat': 40.7667405590595,
#     'lon': -73.9790689945221,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3724',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3725',
#     'external_id': 'e36b5913-8e46-4c2a-b9be-73bdf8ee548b',
#     'name': '2 Ave & E 72 St',
#     'short_name': '6925.09',
#     'lat': 40.7687620293096,
#     'lon': -73.95840793848038,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 41,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3725',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3726',
#     'external_id': '79399e32-a6c6-4732-8ad4-9f9140a86b21',
#     'name': 'Center Blvd & 51 Ave',
#     'short_name': '6179.07',
#     'lat': 40.743366080270214,
#     'lon': -73.95960688591003,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 20,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3726',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3727',
#     'external_id': '3863f086-ae35-4d0e-8c91-2b6e3e5827a1',
#     'name': 'Frost St & Meeker Ave',
#     'short_name': '5371.07',
#     'lat': 40.71766197083994,
#     'lon': -73.94880026578903,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 38,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3727',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3728',
#     'external_id': '78e93937-53d1-4c9b-99ad-0460f908ed2d',
#     'name': 'Pierrepont St & Monroe Pl',
#     'short_name': '4718.08',
#     'lat': 40.69535693320225,
#     'lon': -73.99344027042389,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 24,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3728',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3733',
#     'external_id': '346621b1-0316-4a89-a364-1364194c2c51',
#     'name': 'Avenue C & E 18 St',
#     'short_name': '5769.04',
#     'lat': 40.730563,
#     'lon': -73.973984,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 46,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3733',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3734',
#     'external_id': '2bf9addc-038b-48fe-8794-dde085c5e5dc',
#     'name': 'E 58 St &  1 Ave (NW Corner)',
#     'short_name': '6723.10',
#     'lat': 40.759125,
#     'lon': -73.962658,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 50,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3734',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3737',
#     'external_id': '9394fb49-583f-4426-8d2f-a2b0ffb584d2',
#     'name': 'Stanton St & Norfolk St',
#     'short_name': '5445.07',
#     'lat': 40.720747,
#     'lon': -73.986274,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3737',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3745',
#     'external_id': '59ad8f95-32a4-43de-b1c3-79c667b2d2df',
#     'name': '36 Ave & 31 St',
#     'short_name': ' 6572.08',
#     'lat': 40.75651272984955,
#     'lon': -73.92957486212252,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3745',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3746',
#     'external_id': '90c35466-db3c-4b0d-993e-6e92883773b4',
#     'name': '6 Ave & Broome St',
#     'short_name': '5610.09',
#     'lat': 40.724308321602166,
#     'lon': -74.00473035871983,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 48,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3746',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3747',
#     'external_id': '57dee83e-5f5b-44ea-b7d0-893a9fe372e6',
#     'name': 'E 84 St & 3 Ave',
#     'short_name': '7212.02',
#     'lat': 40.77755374298887,
#     'lon': -73.95512759685516,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3747',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3749',
#     'external_id': '93c28953-7e65-436e-9c5a-9d7ca0e3729f',
#     'name': 'Lexington Ave & E 36 St',
#     'short_name': '6313.10',
#     'lat': 40.747573958954796,
#     'lon': -73.9788007736206,
#     'region_id': 71,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3749',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True}]}}

# %%
r = requests.get('https://gbfs.citibikenyc.com/gbfs/en/station_status.json')
r.status_code
# Out:
# 200

# %% [markdown]
# Using the same steps as above (but all in one line) let's get a hold of the station status:

# %%
station_status = ujson.loads(r.content.decode('utf-8'))
station_status
# Out:
# {'last_updated': 1554070289,
#  'ttl': 10,
#  'data': {'stations': [{'station_id': '72',
#     'num_bikes_available': 49,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070069,
#     'eightd_has_available_keys': False},
#    {'station_id': '79',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069814,
#     'eightd_has_available_keys': False},
#    {'station_id': '82',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068368,
#     'eightd_has_available_keys': False},
#    {'station_id': '83',
#     'num_bikes_available': 37,
#     'num_ebikes_available': 5,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070073,
#     'eightd_has_available_keys': False},
#    {'station_id': '119',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 6,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554067856,
#     'eightd_has_available_keys': False},
#    {'station_id': '120',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070098,
#     'eightd_has_available_keys': False},
#    {'station_id': '127',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070160,
#     'eightd_has_available_keys': False},
#    {'station_id': '128',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 4,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 0,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070284,
#     'eightd_has_available_keys': False},
#    {'station_id': '143',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069942,
#     'eightd_has_available_keys': False},
#    {'station_id': '144',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070138,
#     'eightd_has_available_keys': False},
#    {'station_id': '146',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 5,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069147,
#     'eightd_has_available_keys': False},
#    {'station_id': '150',
#     'num_bikes_available': 26,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070056,
#     'eightd_has_available_keys': False},
#    {'station_id': '151',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 5,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070230,
#     'eightd_has_available_keys': False},
#    {'station_id': '157',
#     'num_bikes_available': 17,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070001,
#     'eightd_has_available_keys': False},
#    {'station_id': '161',
#     'num_bikes_available': 32,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069931,
#     'eightd_has_available_keys': False},
#    {'station_id': '164',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 45,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070286,
#     'eightd_has_available_keys': False},
#    {'station_id': '167',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 40,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070209,
#     'eightd_has_available_keys': False},
#    {'station_id': '168',
#     'num_bikes_available': 24,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070159,
#     'eightd_has_available_keys': False},
#    {'station_id': '173',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 47,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070188,
#     'eightd_has_available_keys': False},
#    {'station_id': '174',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069387,
#     'eightd_has_available_keys': False},
#    {'station_id': '195',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 43,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069837,
#     'eightd_has_available_keys': False},
#    {'station_id': '212',
#     'num_bikes_available': 37,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069312,
#     'eightd_has_available_keys': False},
#    {'station_id': '216',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068909,
#     'eightd_has_available_keys': False},
#    {'station_id': '217',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070168,
#     'eightd_has_available_keys': True},
#    {'station_id': '223',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069832,
#     'eightd_has_available_keys': False},
#    {'station_id': '224',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070206,
#     'eightd_has_available_keys': False},
#    {'station_id': '228',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 53,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069452,
#     'eightd_has_available_keys': False},
#    {'station_id': '229',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 5,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070144,
#     'eightd_has_available_keys': False},
#    {'station_id': '236',
#     'num_bikes_available': 39,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070244,
#     'eightd_has_available_keys': False},
#    {'station_id': '237',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070032,
#     'eightd_has_available_keys': False},
#    {'station_id': '238',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070137,
#     'eightd_has_available_keys': False},
#    {'station_id': '239',
#     'num_bikes_available': 26,
#     'num_ebikes_available': 3,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070150,
#     'eightd_has_available_keys': False},
#    {'station_id': '241',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070254,
#     'eightd_has_available_keys': False},
#    {'station_id': '242',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070018,
#     'eightd_has_available_keys': False},
#    {'station_id': '243',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 3,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069863,
#     'eightd_has_available_keys': False},
#    {'station_id': '244',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 14,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070279,
#     'eightd_has_available_keys': False},
#    {'station_id': '245',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068905,
#     'eightd_has_available_keys': False},
#    {'station_id': '247',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 0,
#     'is_renting': 0,
#     'is_returning': 0,
#     'last_reported': 1,
#     'eightd_has_available_keys': False},
#    {'station_id': '248',
#     'num_bikes_available': 20,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070022,
#     'eightd_has_available_keys': False},
#    {'station_id': '249',
#     'num_bikes_available': 17,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069656,
#     'eightd_has_available_keys': False},
#    {'station_id': '251',
#     'num_bikes_available': 20,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070215,
#     'eightd_has_available_keys': False},
#    {'station_id': '252',
#     'num_bikes_available': 28,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069658,
#     'eightd_has_available_keys': False},
#    {'station_id': '254',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 43,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070012,
#     'eightd_has_available_keys': False},
#    {'station_id': '257',
#     'num_bikes_available': 37,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070101,
#     'eightd_has_available_keys': False},
#    {'station_id': '258',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069980,
#     'eightd_has_available_keys': False},
#    {'station_id': '259',
#     'num_bikes_available': 32,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069744,
#     'eightd_has_available_keys': True},
#    {'station_id': '260',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 0,
#     'is_renting': 0,
#     'is_returning': 0,
#     'last_reported': 1,
#     'eightd_has_available_keys': False},
#    {'station_id': '261',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554067617,
#     'eightd_has_available_keys': False},
#    {'station_id': '262',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 6,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069988,
#     'eightd_has_available_keys': False},
#    {'station_id': '264',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069549,
#     'eightd_has_available_keys': False},
#    {'station_id': '265',
#     'num_bikes_available': 32,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070263,
#     'eightd_has_available_keys': False},
#    {'station_id': '266',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 3,
#     'num_bikes_disabled': 7,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070228,
#     'eightd_has_available_keys': False},
#    {'station_id': '267',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 3,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 43,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070146,
#     'eightd_has_available_keys': False},
#    {'station_id': '268',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070282,
#     'eightd_has_available_keys': False},
#    {'station_id': '270',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070227,
#     'eightd_has_available_keys': False},
#    {'station_id': '274',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069879,
#     'eightd_has_available_keys': False},
#    {'station_id': '275',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 7,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069820,
#     'eightd_has_available_keys': False},
#    {'station_id': '276',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070210,
#     'eightd_has_available_keys': False},
#    {'station_id': '278',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 5,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068742,
#     'eightd_has_available_keys': False},
#    {'station_id': '279',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070089,
#     'eightd_has_available_keys': True},
#    {'station_id': '280',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070074,
#     'eightd_has_available_keys': False},
#    {'station_id': '281',
#     'num_bikes_available': 52,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070003,
#     'eightd_has_available_keys': True},
#    {'station_id': '282',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069842,
#     'eightd_has_available_keys': False},
#    {'station_id': '285',
#     'num_bikes_available': 21,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 28,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069961,
#     'eightd_has_available_keys': False},
#    {'station_id': '289',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069503,
#     'eightd_has_available_keys': False},
#    {'station_id': '291',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069805,
#     'eightd_has_available_keys': False},
#    {'station_id': '293',
#     'num_bikes_available': 33,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070187,
#     'eightd_has_available_keys': False},
#    {'station_id': '295',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070198,
#     'eightd_has_available_keys': False},
#    {'station_id': '296',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069912,
#     'eightd_has_available_keys': False},
#    {'station_id': '297',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 5,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070120,
#     'eightd_has_available_keys': False},
#    {'station_id': '298',
#     'num_bikes_available': 33,
#     'num_ebikes_available': 4,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069955,
#     'eightd_has_available_keys': False},
#    {'station_id': '301',
#     'num_bikes_available': 13,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 44,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070215,
#     'eightd_has_available_keys': False},
#    {'station_id': '302',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069329,
#     'eightd_has_available_keys': False},
#    {'station_id': '303',
#     'num_bikes_available': 60,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070284,
#     'eightd_has_available_keys': False},
#    {'station_id': '304',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 5,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068167,
#     'eightd_has_available_keys': True},
#    {'station_id': '305',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 4,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069930,
#     'eightd_has_available_keys': False},
#    {'station_id': '307',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070231,
#     'eightd_has_available_keys': False},
#    {'station_id': '308',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070207,
#     'eightd_has_available_keys': False},
#    {'station_id': '309',
#     'num_bikes_available': 34,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070171,
#     'eightd_has_available_keys': False},
#    {'station_id': '310',
#     'num_bikes_available': 29,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069466,
#     'eightd_has_available_keys': False},
#    {'station_id': '311',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 9,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070087,
#     'eightd_has_available_keys': False},
#    {'station_id': '312',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070024,
#     'eightd_has_available_keys': False},
#    {'station_id': '313',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068014,
#     'eightd_has_available_keys': False},
#    {'station_id': '314',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 21,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068449,
#     'eightd_has_available_keys': False},
#    {'station_id': '315',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 6,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070240,
#     'eightd_has_available_keys': False},
#    {'station_id': '316',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 40,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069866,
#     'eightd_has_available_keys': False},
#    {'station_id': '317',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 7,
#     'num_docks_available': 37,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070256,
#     'eightd_has_available_keys': False},
#    {'station_id': '319',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069394,
#     'eightd_has_available_keys': False},
#    {'station_id': '320',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069637,
#     'eightd_has_available_keys': False},
#    {'station_id': '321',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 6,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554067412,
#     'eightd_has_available_keys': True},
#    {'station_id': '322',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 0,
#     'is_renting': 0,
#     'is_returning': 0,
#     'last_reported': 1,
#     'eightd_has_available_keys': False},
#    {'station_id': '323',
#     'num_bikes_available': 28,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069224,
#     'eightd_has_available_keys': False},
#    {'station_id': '324',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070070,
#     'eightd_has_available_keys': False},
#    {'station_id': '325',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070114,
#     'eightd_has_available_keys': False},
#    {'station_id': '326',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070260,
#     'eightd_has_available_keys': False},
#    {'station_id': '327',
#     'num_bikes_available': 35,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070083,
#     'eightd_has_available_keys': False},
#    {'station_id': '328',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070248,
#     'eightd_has_available_keys': False},
#    {'station_id': '330',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 36,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069848,
#     'eightd_has_available_keys': False},
#    {'station_id': '331',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069999,
#     'eightd_has_available_keys': False},
#    {'station_id': '332',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069783,
#     'eightd_has_available_keys': False},
#    {'station_id': '334',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070234,
#     'eightd_has_available_keys': False},
#    {'station_id': '335',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070272,
#     'eightd_has_available_keys': False},
#    {'station_id': '336',
#     'num_bikes_available': 32,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070193,
#     'eightd_has_available_keys': False},
#    {'station_id': '337',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068991,
#     'eightd_has_available_keys': False},
#    {'station_id': '339',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070100,
#     'eightd_has_available_keys': False},
#    {'station_id': '340',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069443,
#     'eightd_has_available_keys': False},
#    {'station_id': '341',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 4,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069873,
#     'eightd_has_available_keys': False},
#    {'station_id': '342',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 5,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069755,
#     'eightd_has_available_keys': False},
#    {'station_id': '343',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070007,
#     'eightd_has_available_keys': False},
#    {'station_id': '344',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070047,
#     'eightd_has_available_keys': False},
#    {'station_id': '346',
#     'num_bikes_available': 17,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070199,
#     'eightd_has_available_keys': False},
#    {'station_id': '347',
#     'num_bikes_available': 30,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070100,
#     'eightd_has_available_keys': False},
#    {'station_id': '349',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 55,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069522,
#     'eightd_has_available_keys': False},
#    {'station_id': '350',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 7,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070276,
#     'eightd_has_available_keys': False},
#    {'station_id': '351',
#     'num_bikes_available': 34,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070246,
#     'eightd_has_available_keys': False},
#    {'station_id': '353',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070014,
#     'eightd_has_available_keys': False},
#    {'station_id': '354',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069437,
#     'eightd_has_available_keys': False},
#    {'station_id': '355',
#     'num_bikes_available': 37,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070068,
#     'eightd_has_available_keys': False},
#    {'station_id': '356',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069765,
#     'eightd_has_available_keys': False},
#    {'station_id': '357',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069069,
#     'eightd_has_available_keys': False},
#    {'station_id': '358',
#     'num_bikes_available': 43,
#     'num_ebikes_available': 7,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070231,
#     'eightd_has_available_keys': False},
#    {'station_id': '359',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 56,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554066199,
#     'eightd_has_available_keys': False},
#    {'station_id': '360',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 34,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069832,
#     'eightd_has_available_keys': False},
#    {'station_id': '361',
#     'num_bikes_available': 26,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 5,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070152,
#     'eightd_has_available_keys': False},
#    {'station_id': '362',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 44,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070029,
#     'eightd_has_available_keys': False},
#    {'station_id': '363',
#     'num_bikes_available': 29,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070069,
#     'eightd_has_available_keys': False},
#    {'station_id': '364',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070232,
#     'eightd_has_available_keys': False},
#    {'station_id': '365',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068915,
#     'eightd_has_available_keys': False},
#    {'station_id': '366',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070098,
#     'eightd_has_available_keys': False},
#    {'station_id': '368',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070181,
#     'eightd_has_available_keys': False},
#    {'station_id': '369',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 0,
#     'is_renting': 0,
#     'is_returning': 0,
#     'last_reported': 1,
#     'eightd_has_available_keys': False},
#    {'station_id': '372',
#     'num_bikes_available': 20,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069770,
#     'eightd_has_available_keys': False},
#    {'station_id': '373',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070135,
#     'eightd_has_available_keys': False},
#    {'station_id': '376',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070012,
#     'eightd_has_available_keys': False},
#    {'station_id': '377',
#     'num_bikes_available': 40,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070254,
#     'eightd_has_available_keys': False},
#    {'station_id': '379',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 32,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070024,
#     'eightd_has_available_keys': False},
#    {'station_id': '380',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 3,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 32,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070236,
#     'eightd_has_available_keys': False},
#    {'station_id': '382',
#     'num_bikes_available': 29,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070238,
#     'eightd_has_available_keys': False},
#    {'station_id': '383',
#     'num_bikes_available': 20,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 5,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069832,
#     'eightd_has_available_keys': False},
#    {'station_id': '385',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069507,
#     'eightd_has_available_keys': False},
#    {'station_id': '386',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554067126,
#     'eightd_has_available_keys': False},
#    {'station_id': '387',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 5,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069979,
#     'eightd_has_available_keys': False},
#    {'station_id': '388',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 33,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070027,
#     'eightd_has_available_keys': False},
#    {'station_id': '389',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068787,
#     'eightd_has_available_keys': False},
#    {'station_id': '390',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070013,
#     'eightd_has_available_keys': False},
#    {'station_id': '391',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 3,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070268,
#     'eightd_has_available_keys': False},
#    {'station_id': '392',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069725,
#     'eightd_has_available_keys': False},
#    {'station_id': '393',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 28,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070196,
#     'eightd_has_available_keys': False},
#    {'station_id': '394',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069993,
#     'eightd_has_available_keys': False},
#    {'station_id': '396',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068947,
#     'eightd_has_available_keys': False},
#    {'station_id': '397',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 0,
#     'is_returning': 0,
#     'last_reported': 1,
#     'eightd_has_available_keys': False},
#    {'station_id': '398',
#     'num_bikes_available': 29,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
# ...
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554055778,
#     'eightd_has_available_keys': False},
#    {'station_id': '3662',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070255,
#     'eightd_has_available_keys': False},
#    {'station_id': '3664',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069695,
#     'eightd_has_available_keys': False},
#    {'station_id': '3668',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069907,
#     'eightd_has_available_keys': False},
#    {'station_id': '3671',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069652,
#     'eightd_has_available_keys': False},
#    {'station_id': '3673',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069160,
#     'eightd_has_available_keys': False},
#    {'station_id': '3674',
#     'num_bikes_available': 24,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069273,
#     'eightd_has_available_keys': False},
#    {'station_id': '3675',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069809,
#     'eightd_has_available_keys': False},
#    {'station_id': '3676',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069668,
#     'eightd_has_available_keys': False},
#    {'station_id': '3677',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554045139,
#     'eightd_has_available_keys': False},
#    {'station_id': '3678',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554015208,
#     'eightd_has_available_keys': False},
#    {'station_id': '3679',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554060266,
#     'eightd_has_available_keys': False},
#    {'station_id': '3680',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 54,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070245,
#     'eightd_has_available_keys': False},
#    {'station_id': '3681',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069722,
#     'eightd_has_available_keys': False},
#    {'station_id': '3684',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 7,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070280,
#     'eightd_has_available_keys': False},
#    {'station_id': '3686',
#     'num_bikes_available': 33,
#     'num_ebikes_available': 5,
#     'num_bikes_disabled': 5,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070217,
#     'eightd_has_available_keys': False},
#    {'station_id': '3687',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 7,
#     'num_docks_available': 44,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070215,
#     'eightd_has_available_keys': False},
#    {'station_id': '3689',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 43,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070202,
#     'eightd_has_available_keys': False},
#    {'station_id': '3690',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 4,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069986,
#     'eightd_has_available_keys': False},
#    {'station_id': '3691',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070017,
#     'eightd_has_available_keys': False},
#    {'station_id': '3692',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068541,
#     'eightd_has_available_keys': False},
#    {'station_id': '3693',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069861,
#     'eightd_has_available_keys': False},
#    {'station_id': '3694',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554067165,
#     'eightd_has_available_keys': False},
#    {'station_id': '3697',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 41,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069871,
#     'eightd_has_available_keys': False},
#    {'station_id': '3699',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069768,
#     'eightd_has_available_keys': False},
#    {'station_id': '3701',
#     'num_bikes_available': 30,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069650,
#     'eightd_has_available_keys': False},
#    {'station_id': '3704',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554065785,
#     'eightd_has_available_keys': False},
#    {'station_id': '3707',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 45,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070054,
#     'eightd_has_available_keys': False},
#    {'station_id': '3708',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070126,
#     'eightd_has_available_keys': False},
#    {'station_id': '3709',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 38,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070093,
#     'eightd_has_available_keys': False},
#    {'station_id': '3711',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 43,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070008,
#     'eightd_has_available_keys': False},
#    {'station_id': '3712',
#     'num_bikes_available': 31,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070176,
#     'eightd_has_available_keys': False},
#    {'station_id': '3714',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 49,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069502,
#     'eightd_has_available_keys': False},
#    {'station_id': '3715',
#     'num_bikes_available': 29,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070280,
#     'eightd_has_available_keys': False},
#    {'station_id': '3716',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554066448,
#     'eightd_has_available_keys': False},
#    {'station_id': '3718',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 31,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069721,
#     'eightd_has_available_keys': False},
#    {'station_id': '3720',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069807,
#     'eightd_has_available_keys': False},
#    {'station_id': '3721',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 28,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070197,
#     'eightd_has_available_keys': False},
#    {'station_id': '3723',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068850,
#     'eightd_has_available_keys': True},
#    {'station_id': '3724',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 35,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069476,
#     'eightd_has_available_keys': False},
#    {'station_id': '3725',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 35,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070076,
#     'eightd_has_available_keys': False},
#    {'station_id': '3726',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069947,
#     'eightd_has_available_keys': False},
#    {'station_id': '3727',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069571,
#     'eightd_has_available_keys': False},
#    {'station_id': '3728',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069223,
#     'eightd_has_available_keys': False},
#    {'station_id': '3733',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 5,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 36,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069288,
#     'eightd_has_available_keys': False},
#    {'station_id': '3734',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 48,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070085,
#     'eightd_has_available_keys': False},
#    {'station_id': '3737',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554069992,
#     'eightd_has_available_keys': False},
#    {'station_id': '3745',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554068752,
#     'eightd_has_available_keys': False},
#    {'station_id': '3746',
#     'num_bikes_available': 41,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070074,
#     'eightd_has_available_keys': False},
#    {'station_id': '3747',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070193,
#     'eightd_has_available_keys': False},
#    {'station_id': '3749',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1554070066,
#     'eightd_has_available_keys': False}]}}
