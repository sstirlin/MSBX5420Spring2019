# %% [markdown]
# # JSON tutorial
#
# Last time we learned about a Python-specific serialization format called `pickle`.  This is often used "under the hood" (e.g. in Spark) to serialize data and functions, but is rarely used beyond that.
#
# One important data serialization format that IS often used for data interchange is `json`.  It is widely used because it is simple and formatted in human-readable text files.  Although it came out of the Javascript language, support is ubiquitous across many languages.

# %% [markdown]
# ## File navigation in Python
#
# In order to read one of the json files into Python, we need to learn a little about how to navigate the filesystem in Python.  First, we could "hardcode" our file path like this:

# %%
jsonpath = 'cwl-data/data/structured/structured-2018-01-14-neworleans/structured-1515984523-6592b573-b485-58b0-963e-6be0b4d02f6c.json'

# %% [markdown]
# but that's not particularly robust.  For example, this wouldn't work in Windows because there directories are separated by `\` instead of `/`.
#
# Python has some nifty functions to avoid dealing with all of this cross-platform nastiness:

# %%
import os
datadir = os.path.join('./', 'cwl-data', 'data', 'structured', 'structured-2018-01-14-neworleans')

jsonfile = 'structured-1515984523-6592b573-b485-58b0-963e-6be0b4d02f6c.json'

jsonpath = os.path.join(datadir, jsonfile)
print(jsonpath)
# Out:
# ./cwl-data/data/structured/structured-2018-01-14-neworleans/structured-1515984523-6592b573-b485-58b0-963e-6be0b4d02f6c.json

# %% [markdown]
# We can open the file and read the raw data:

# %%
# open the file
with open(jsonpath, 'r') as f:
    rawdata = f.read()

# %%
type(rawdata)
# Out:
# str

# %%
rawdata
# Out:
# '{"title": "ww2", "platform": "ps4", "id": "6592b573-b485-58b0-963e-6be0b4d02f6c", "series_id": "champs-grand-finals-1", "start_time_s": 1515984053, "end_time_s": 1515984523, "duration_ms": 470000, "mode": "Search & Destroy", "map": "Sainte Marie du Mont", "rounds": 9, "teams": [{"name": "TEAM KALIBER", "score": 6, "is_victor": true, "round_scores": [1, 1, 0, 1, 1, 0, 0, 1, 1], "side": "home"}, {"name": "LUMINOSITY GAMING", "score": 3, "is_victor": false, "round_scores": [0, 0, 1, 0, 0, 1, 1, 0, 0], "side": "away"}], "players": [{"name": "ACCURACY", "team": "TEAM KALIBER", "kills": 8, "deaths": 4, "kd": 2.0, "kills_per_10min": 10.2, "deaths_per_10min": 5.1, "assists": 8, "headshots": 2, "suicides": 0, "team_kills": 0, "team_deaths": 0, "stayed_alive_kills": 8, "hits": 53, "shots": 195, "accuracy": 27.2, "num_lives": 9, "time_alive_s": 398.2, "avg_time_per_life_s": 44.2, "fave_weapon": "BAR", "fave_division": "Armored", "fave_training": "Scoped", "fave_scorestreaks": ["Fighter Pilot", "Glide Bomb", "Mortar Strike"], "2piece": 0, "3piece": 1, "4piece": 0, "4streak": 0, "5streak": 0, "6streak": 0, "7streak": 0, "8+streak": 0, "scorestreaks_earned": 0, "scorestreaks_used": 0, "scorestreaks_deployed": 0, "scorestreaks_kills": 0, "scorestreaks_assists": 0, "snd_firstbloods": 0, "snd_pickups": 1, "snd_plants": 1, "snd_defuses": 1, "snd_sneak_defuses": 0, "snd_rounds": 9, "snd_firstdeaths": 2, "snd_survives": 5, "snd_1kill_round": 1, "snd_2kill_round": 2, "snd_3kill_round": 1, "snd_4kill_round": 0}, {"name": "CHINO", "team": "TEAM KALIBER", "kills": 8, "deaths": 7, "kd": 1.14, "kills_per_10min": 10.2, "deaths_per_10min": 8.9, "assists": 1, "headshots": 1, "suicides": 0, "team_kills": 0, "team_deaths": 0, "stayed_alive_kills": 8, "hits": 28, "shots": 128, "accuracy": 21.9, "num_lives": 9, "time_alive_s": 368.4, "avg_time_per_life_s": 40.9, "fave_weapon": "BAR", "fave_division": "Armored", "fave_training": "Scoped", "fave_scorestreaks": ["Fighter Pilot", "Glide Bomb", "Mortar Strike"], "2piece": 1, "3piece": 1, "4piece": 0, "4streak": 0, "5streak": 0, "6streak": 0, "7streak": 0, "8+streak": 0, "scorestreaks_earned": 0, "scorestreaks_used": 0, "scorestreaks_deployed": 0, "scorestreaks_kills": 0, "scorestreaks_assists": 0, "snd_firstbloods": 2, "snd_pickups": 0, "snd_plants": 0, "snd_defuses": 0, "snd_sneak_defuses": 0, "snd_rounds": 9, "snd_firstdeaths": 2, "snd_survives": 2, "snd_1kill_round": 2, "snd_2kill_round": 0, "snd_3kill_round": 2, "snd_4kill_round": 0}, {"name": "KENNY", "team": "TEAM KALIBER", "kills": 7, "deaths": 5, "kd": 1.4, "kills_per_10min": 8.9, "deaths_per_10min": 6.4, "assists": 0, "headshots": 0, "suicides": 0, "team_kills": 0, "team_deaths": 0, "stayed_alive_kills": 4, "hits": 22, "shots": 68, "accuracy": 32.4, "num_lives": 9, "time_alive_s": 374.2, "avg_time_per_life_s": 41.6, "fave_weapon": "BAR", "fave_division": "Armored", "fave_training": "Scoped", "fave_scorestreaks": ["Fighter Pilot", "Glide Bomb", "Mortar Strike"], "2piece": 1, "3piece": 0, "4piece": 0, "4streak": 0, "5streak": 0, "6streak": 0, "7streak": 0, "8+streak": 0, "scorestreaks_earned": 0, "scorestreaks_used": 0, "scorestreaks_deployed": 0, "scorestreaks_kills": 0, "scorestreaks_assists": 0, "snd_firstbloods": 0, "snd_pickups": 0, "snd_plants": 0, "snd_defuses": 0, "snd_sneak_defuses": 0, "snd_rounds": 9, "snd_firstdeaths": 0, "snd_survives": 4, "snd_1kill_round": 3, "snd_2kill_round": 2, "snd_3kill_round": 0, "snd_4kill_round": 0}, {"name": "THEORY", "team": "TEAM KALIBER", "kills": 4, "deaths": 7, "kd": 0.57, "kills_per_10min": 5.1, "deaths_per_10min": 8.9, "assists": 0, "headshots": 2, "suicides": 0, "team_kills": 0, "team_deaths": 0, "stayed_alive_kills": 3, "hits": 18, "shots": 120, "accuracy": 15.0, "num_lives": 9, "time_alive_s": 294.7, "avg_time_per_life_s": 32.7, "fave_weapon": "PPSh-41", "fave_division": "Expeditionary", "fave_training": "Hunker", "fave_scorestreaks": ["Fighter Pilot", "Glide Bomb", "Mortar Strike"], "2piece": 0, "3piece": ...

# %% [markdown]
# ## Deserialization
#
# We have the raw text read in as a string, but we want to "unpack" it.  We call this "deserialization":

# %%
import ujson

# deserialize the data from json format
data = ujson.loads(rawdata)

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {'title': 'ww2',
#  'platform': 'ps4',
#  'id': '6592b573-b485-58b0-963e-6be0b4d02f6c',
#  'series_id': 'champs-grand-finals-1',
#  'start_time_s': 1515984053,
#  'end_time_s': 1515984523,
#  'duration_ms': 470000,
#  'mode': 'Search & Destroy',
#  'map': 'Sainte Marie du Mont',
#  'rounds': 9,
#  'teams': [{'name': 'TEAM KALIBER',
#    'score': 6,
#    'is_victor': True,
#    'round_scores': [1, 1, 0, 1, 1, 0, 0, 1, 1],
#    'side': 'home'},
#   {'name': 'LUMINOSITY GAMING',
#    'score': 3,
#    'is_victor': False,
#    'round_scores': [0, 0, 1, 0, 0, 1, 1, 0, 0],
#    'side': 'away'}],
#  'players': [{'name': 'ACCURACY',
#    'team': 'TEAM KALIBER',
#    'kills': 8,
#    'deaths': 4,
#    'kd': 2.0,
#    'kills_per_10min': 10.2,
#    'deaths_per_10min': 5.1,
#    'assists': 8,
#    'headshots': 2,
#    'suicides': 0,
#    'team_kills': 0,
#    'team_deaths': 0,
#    'stayed_alive_kills': 8,
#    'hits': 53,
#    'shots': 195,
#    'accuracy': 27.2,
#    'num_lives': 9,
#    'time_alive_s': 398.2,
#    'avg_time_per_life_s': 44.2,
#    'fave_weapon': 'BAR',
#    'fave_division': 'Armored',
#    'fave_training': 'Scoped',
#    'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#    '2piece': 0,
#    '3piece': 1,
#    '4piece': 0,
#    '4streak': 0,
#    '5streak': 0,
#    '6streak': 0,
#    '7streak': 0,
#    '8+streak': 0,
#    'scorestreaks_earned': 0,
#    'scorestreaks_used': 0,
#    'scorestreaks_deployed': 0,
#    'scorestreaks_kills': 0,
#    'scorestreaks_assists': 0,
#    'snd_firstbloods': 0,
#    'snd_pickups': 1,
#    'snd_plants': 1,
#    'snd_defuses': 1,
#    'snd_sneak_defuses': 0,
#    'snd_rounds': 9,
#    'snd_firstdeaths': 2,
#    'snd_survives': 5,
#    'snd_1kill_round': 1,
#    'snd_2kill_round': 2,
#    'snd_3kill_round': 1,
#    'snd_4kill_round': 0},
#   {'name': 'CHINO',
#    'team': 'TEAM KALIBER',
#    'kills': 8,
#    'deaths': 7,
#    'kd': 1.1400000000000001,
#    'kills_per_10min': 10.2,
#    'deaths_per_10min': 8.9,
#    'assists': 1,
#    'headshots': 1,
#    'suicides': 0,
#    'team_kills': 0,
#    'team_deaths': 0,
#    'stayed_alive_kills': 8,
#    'hits': 28,
#    'shots': 128,
#    'accuracy': 21.9,
#    'num_lives': 9,
#    'time_alive_s': 368.4,
#    'avg_time_per_life_s': 40.9,
#    'fave_weapon': 'BAR',
#    'fave_division': 'Armored',
#    'fave_training': 'Scoped',
#    'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#    '2piece': 1,
#    '3piece': 1,
#    '4piece': 0,
#    '4streak': 0,
#    '5streak': 0,
#    '6streak': 0,
#    '7streak': 0,
#    '8+streak': 0,
#    'scorestreaks_earned': 0,
#    'scorestreaks_used': 0,
#    'scorestreaks_deployed': 0,
#    'scorestreaks_kills': 0,
#    'scorestreaks_assists': 0,
#    'snd_firstbloods': 2,
#    'snd_pickups': 0,
#    'snd_plants': 0,
#    'snd_defuses': 0,
#    'snd_sneak_defuses': 0,
#    'snd_rounds': 9,
#    'snd_firstdeaths': 2,
#    'snd_survives': 2,
#    'snd_1kill_round': 2,
#    'snd_2kill_round': 0,
#    'snd_3kill_round': 2,
#    'snd_4kill_round': 0},
#   {'name': 'KENNY',
#    'team': 'TEAM KALIBER',
#    'kills': 7,
#    'deaths': 5,
#    'kd': 1.4,
#    'kills_per_10min': 8.9,
#    'deaths_per_10min': 6.4,
#    'assists': 0,
#    'headshots': 0,
#    'suicides': 0,
#    'team_kills': 0,
#    'team_deaths': 0,
#    'stayed_alive_kills': 4,
#    'hits': 22,
#    'shots': 68,
#    'accuracy': 32.4,
#    'num_lives': 9,
#    'time_alive_s': 374.2,
#    'avg_time_per_life_s': 41.6,
#    'fave_weapon': 'BAR',
#    'fave_division': 'Armored',
#    'fave_training': 'Scoped',
#    'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#    '2piece': 1,
#    '3piece': 0,
#    '4piece': 0,
#    '4streak': 0,
#    '5streak': 0,
#    '6streak': 0,
#    '7streak': 0,
#    '8+streak': 0,
#    'scorestreaks_earned': 0,
#    'scorestreaks_used': 0,
#    'scorestreaks_deployed': 0,
#    'scorestreaks_kills': 0,
#    'scorestreaks_assists': 0,
#    'snd_firstbloods': 0,
#    'snd_pickups': 0,
#    'snd_plants': 0,
#    'snd_defuses': 0,
#    'snd_sneak_defuses': 0,
#    'snd_rounds': 9,
#    'snd_firstdeaths': 0,
#    'snd_survives': 4,
#    'snd_1kill_round': 3,
#    'snd_2kill_round': 2,
#    'snd_3kill_round': 0,
#    'snd_4kill_round': 0},
#   {'name': 'THEORY',
#    'team': 'TEAM KALIBER',
#    'kills': 4,
#    'deaths': 7,
#    'kd': 0.5700000000000001,
#    'kills_per_10min': 5.1,
#    'deaths_per_10min': 8.9,
#    'assists': 0,
#    'headshots': 2,
#    'suicides': 0,
#    'team_kills': 0,
#    'team_deaths': 0,
#    'stayed_alive_kills': 3,
#    'hits': 18,
#    'shots': 120,
#    'accuracy': 15.0,
#    'num_lives': 9,
#    'time_alive_s': 294.7,
#    'avg_time_per_life_s': 32.7,
#    'fave_weapon': 'PPSh-41',
#    'fave_division': 'Expeditionary',
#    'fave_training': 'Hunker',
#    'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#    '2piece': 0,
#    '3piece': 0,
#    '4piece': 0,
#    '4streak': 0,
#    '5streak': 0,
#    '6streak': 0,
#    '7streak': 0,
#    '8+streak': 0,
#    'scorestreaks_earned': 0,
#    'scorestreaks_used': 0,
#    'scorestreaks_deployed': 0,
#    'scorestreaks_kills': 0,
#    'scorestreaks_assists': 0,
#    'snd_firstbloods': 0,
#    'snd_pickups': 5,
#    'snd_plants': 4,
#    'snd_defuses': 0,
#    'snd_sneak_defuses': 0,
#    'snd_rounds': 9,
#    'snd_firstdeaths': 3,
#    'snd_survives': 2,
#    'snd_1kill_round': 2,
#    'snd_2kill_round': 1,
#    'snd_3kill_round': 0,
#    'snd_4kill_round': 0},
#   {'name': 'JKAP',
#    'team': 'LUMINOSITY GAMING',
#    'kills': 7,
#    'deaths': 7,
#    'kd': 1.0,
#    'kills_per_10min': 8.9,
#    'deaths_per_10min': 8.9,
#    'assists': 3,
#    'headshots': 2,
#    'suicides': 0,
#    'team_kills': 0,
#    'team_deaths': 0,
#    'stayed_alive_kills': 6,
#    'hits': 41,
#    'shots': 211,
#    'accuracy': 19.4,
#    'num_lives': 9,
#    'time_alive_s': 383.0,
#    'avg_time_per_life_s': 42.6,
#    'fave_weapon': 'STG-44',
#    'fave_division': 'Armored',
#    'fave_training': 'Scoped',
#    'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#    '2piece': 1,
#    '3piece': 0,
#    '4piece': 0,
#    '4streak': 0,
#    '5streak': 0,
#    '6streak': 0,
#    '7streak': 0,
#    '8+streak': 0,
#    'scorestreaks_earned': 0,
#    'scorestreaks_used': 0,
#    'scorestreaks_deployed': 0,
#    'scorestreaks_kills': 0,
#    'scorestreaks_assists': 0,
#    'snd_firstbloods': 2,
#    'snd_pickups': 3,
#    'snd_plants': 1,
#    'snd_defuses': 1,
#    'snd_sneak_defuses': 0,
#    'snd_rounds': 9,
#    'snd_firstdeaths': 1,
#    'snd_survives': 2,
#    'snd_1kill_round': 5,
#    'snd_2kill_round': 1,
#    'snd_3kill_round': 0,
#    'snd_4kill_round': 0},
#   {'name': 'JOHN',
#    'team': 'LUMINOSITY GAMING',
#    'kills': 5,
#    'deaths': 6,
#    'kd': 0.8300000000000001,
#    'kills_per_10min': 6.4,
#    'deaths_per_10min': 7.7,
#    'assists': 3,
#    'headshots': 0,
#    'suicides': 0,
#    'team_kills': 0,
#    'team_deaths': 0,
#    'stayed_alive_kills': 4,
#    'hits': 25,
#    'shots': 214,
#    'accuracy': 11.7,
#    'num_lives': 9,
#    'time_alive_s': 403.4,
#    'avg_time_per_life_s': 44.8,
#    'fave_weapon': 'PPSh-41',
#    'fave_division': 'Armored',
#    'fave_training': 'Inconspicuous',
#    'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Artillery Barrage'],
#    '2piece': 1,
#    '3piece': 0,
#    '4piece': 0,
#    '4streak': 0,
#    '5streak': 0,
#    '6streak': 0,
#    '7streak': 0,
#    '8+streak': 0,
#    'scorestreaks_earned': 2,
#    'scorestreaks_used': 2,
#    'scorestreaks_deployed': 2,
#    'scorestreaks_kills': 0,
#    'scorestreaks_assists': 0,
#    'snd_firstbloods': 1,
#    'snd_pickups': 1,
#    'snd_plants': 1,
#    'snd_defuses': 1,
#    'snd_sneak_defuses': 0,
#    'snd_rounds': 9,
#    'snd_firstdeaths': 1,
#    'snd_survives': 3,
#    'snd_1kill_round': 1,
#    'snd_2kill_round': 2,
#    'snd_3kill_round': 0,
#    'snd_4kill_round': 0},
#   {'name': 'OCTANE',
#    'team': 'LUMINOSITY GAMING',
#    'kills': 3,
#    'deaths': 8,
#    'kd': 0.38,
#    'kills_per_10min': 3.8,
#    'deaths_per_10min': 10.2,
#    'assists': 3,
#    'headshots': 1,
#    'suicides': 0,
#    'team_kills': 0,
#    'team_deaths': 0,
#    'stayed_alive_kills': 2,
#    'hits': 22,
#    'shots': 116,
#    'accuracy': 19.0,
#    'num_lives': 9,
#    'time_alive_s': 362.1,
#    'avg_time_per_life_s': 40.2,
#    'fave_weapon': 'STG-44',
#    'fave_division': 'Armored',
#    'fave_training': 'Scoped',
#    'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#    '2piece': 1,
#    '3piece': 0,
#    '4piece': 0,
#    '4streak': 0,
#    '5streak': 0,
#    '6streak': 0,
#    '7streak': 0,
#    '8+streak': 0,
#    'scorestreaks_earned': 0,
#    'scorestreaks_used': 0,
#    'scorestreaks_deployed': 0,
#    'scorestreaks_kills': 0,
#    'scorestreaks_assists': 0,
#    'snd_firstbloods': 1,
#    'snd_pickups': 0,
#    'snd_plants': 0,
#    'snd_defuses': 0,
#    'snd_sneak_defuses': 0,
#    'snd_rounds': 9,
#    'snd_firstdeaths': 0,
#    'snd_survives': 1,
#    'snd_1kill_round': 1,
#    'snd_2kill_round': 1,
#    'snd_3kill_round': 0,
#    'snd_4kill_round': 0},
#   {'name': 'SLACKED',
#    'team': 'LUMINOSITY GAMING',
#    'kills': 8,
#    'deaths': 6,
#    'kd': 1.33,
#    'kills_per_10min': 10.2,
#    'deaths_per_10min': 7.7,
#    'assists': 1,
#    'headshots': 1,
#    'suicides': 0,
#    'team_kills': 0,
#    'team_deaths': 0,
#    'stayed_alive_kills': 8,
#    'hits': 26,
#    'shots': 169,
#    'accuracy': 15.4,
#    'num_lives': 9,
#    'time_alive_s': 413.8,
#    'avg_time_per_life_s': 46.0,
#    'fave_weapon': 'PPSh-41',
#    'fave_division': 'Mountain',
#    'fave_training': 'Hunker',
#    'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#    '2piece': 1,
#    '3piece': 0,
#    '4piece': 0,
#    '4streak': 0,
#    '5streak': 0,
#    '6streak': 0,
#    '7streak': 0,
#    '8+streak': 0,
#    'scorestreaks_earned': 0,
#    'scorestreaks_used': 0,
#    'scorestreaks_deployed': 0,
#    'scorestreaks_kills': 0,
#    'scorestreaks_assists': 0,
#    'snd_firstbloods': 3,
#    'snd_pickups': 0,
#    'snd_plants': 0,
#    'snd_defuses': 0,
#    'snd_sneak_defuses': 0,
#    'snd_rounds': 9,
#    'snd_firstdeaths': 0,
#    'snd_survives': 3,
#    'snd_1kill_round': 3,
#    'snd_2kill_round': 1,
#    'snd_3kill_round': 1,
#    'snd_4kill_round': 0}],
#  'events': [{'type': 'roundstart',
#    'time_ms': 0,
#    'round': 1,
#    'round_time_ms': 0,
#    'data': {}},
#   {'type': 'spawn',
#    'time_ms': 0,
#    'round': 1,
#    'round_time_ms': 0,
#    'data': {'id': 'ACCURACY', 'pos': {'y': 33, 'x': 434}, 'life': 0}},
#   {'type': 'spawn',
#    'time_ms': 0,
#    'round': 1,
#    'round_time_ms': 0,
#    'data': {'id': 'CHINO', 'pos': {'y': 38, 'x': 445}, 'life': 1}},
#   {'type': 'spawn',
#    'time_ms': 0,
#    'round': 1,
#    'round_time_ms': 0,
#    'data': {'id': 'THEORY', 'pos': {'y': 44, 'x': 428}, 'life': 2}},
#   {'type': 'spawn',
#    'time_ms': 0,
#    'round': 1,
#    'round_time_ms': 0,
#    'data': {'id': 'KENNY', 'pos': {'y': 44, 'x': 456}, 'life': 3}},
#   {'type': 'spawn',
#    'time_ms': 0,
#    'round': 1,
#    'round_time_ms': 0,
#    'data': {'id': 'OCTANE', 'pos': {'y': 895, 'x': 488}, 'life': 4}},
#   {'type': 'spawn',
#    'time_ms': 0,
#    'round': 1,
#    'round_time_ms': 0,
#    'data': {'id': 'JKAP', 'pos': {'y': 895, 'x': 515}, 'life': 5}},
#   {'type': 'spawn',
#    'time_ms': 0,
#    'round': 1,
#    'round_time_ms': 0,
#    'data': {'id': 'SLACKED', 'pos': {'y': 895, 'x': 504}, 'life': 6}},
#   {'type': 'spawn',
#    'time_ms': 0,
#    'round': 1,
#    'round_time_ms': 0,
#    'data': {'id': 'JOHN', 'pos': {'y': 895, 'x': 471}, 'life': 7}},
#   {'type': 'death',
#    'time_ms': 34650,
#    'round': 1,
#    'round_time_ms': 34650,
#    'data': {'id': 'JOHN',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'CHINO',
#      'pos': {'y': 461, 'x': 622},
#      'weapon': 'BAR',
#      'life': 1},
#     'pos': {'y': 496, 'x': 544},
#     'life': 7}},
#   {'type': 'death',
#    'time_ms': 36650,
#    'round': 1,
#    'round_time_ms': 36650,
#    'data': {'id': 'SLACKED',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'ACCURACY',
#      'pos': {'y': 379, 'x': 674},
#      'weapon': 'BAR',
#      'life': 0},
#     'pos': {'y': 493, 'x': 544},
#     'life': 6}},
#   {'type': 'death',
#    'time_ms': 39950,
#    'round': 1,
#    'round_time_ms': 39950,
#    'data': {'id': 'JKAP',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'THEORY',
#      'pos': {'y': 477, 'x': 661},
#      'weapon': 'PPSh-41',
#      'life': 2},
#     'pos': {'y': 549, 'x': 650},
#     'life': 5}},
#   {'type': 'death',
#    'time_ms': 45850,
#    'round': 1,
#    'round_time_ms': 45850,
#    'data': {'id': 'CHINO',
#     'attacker': {'means_of_death': 'head_shot',
#      'id': 'OCTANE',
#      'pos': {'y': 577, 'x': 670},
#      'weapon': 'STG-44',
#      'life': 4},
#     'pos': {'y': 461, 'x': 624},
#     'life': 1}},
#   {'type': 'death',
#    'time_ms': 55050,
#    'round': 1,
#    'round_time_ms': 55050,
#    'data': {'id': 'OCTANE',
#     'attacker': {'means_of_death': 'head_shot',
#      'id': 'THEORY',
#      'pos': {'y': 461, 'x': 628},
#      'weapon': 'PPSh-41',
#      'life': 2},
#     'pos': {'y': 598, 'x': 672},
#     'life': 4}},
#   {'type': 'roundend',
#    'time_ms': 55150,
#    'round': 1,
#    'round_time_ms': 55150,
#    'data': {'score2': 0, 'score1': 1}},
#   {'type': 'spawn',
#    'time_ms': 71850,
#    'round': 1,
#    'round_time_ms': 71850,
#    'data': {'id': 'SLACKED', 'pos': {'y': 44, 'x': 456}, 'life': 8}},
#   {'type': 'spawn',
#    'time_ms': 71900,
#    'round': 1,
#    'round_time_ms': 71900,
#    'data': {'id': 'JOHN', 'pos': {'y': 38, 'x': 445}, 'life': 9}},
#   {'type': 'spawn',
#    'time_ms': 71950,
#    'round': 1,
#    'round_time_ms': 71950,
#    'data': {'id': 'KENNY', 'pos': {'y': 895, 'x': 471}, 'life': 10}},
#   {'type': 'spawn',
#    'time_ms': 72050,
#    'round': 1,
#    'round_time_ms': 72050,
#    'data': {'id': 'CHINO', 'pos': {'y': 895, 'x': 488}, 'life': 12}},
#   {'type': 'spawn',
#    'time_ms': 72100,
#    'round': 1,
#    'round_time_ms': 72100,
#    'data': {'id': 'THEORY', 'pos': {'y': 895, 'x': 504}, 'life': 11}},
#   {'type': 'spawn',
#    'time_ms': 72100,
#    'round': 1,
#    'round_time_ms': 72100,
#    'data': {'id': 'JKAP', 'pos': {'y': 33, 'x': 434}, 'life': 13}},
#   {'type': 'spawn',
#    'time_ms': 72150,
#    'round': 1,
#    'round_time_ms': 72150,
#    'data': {'id': 'ACCURACY', 'pos': {'y': 895, 'x': 515}, 'life': 14}},
#   {'type': 'spawn',
#    'time_ms': 72200,
#    'round': 1,
#    'round_time_ms': 72200,
#    'data': {'id': 'OCTANE', 'pos': {'y': 44, 'x': 428}, 'life': 15}},
#   {'type': 'roundstart',
#    'time_ms': 76700,
#    'round': 2,
#    'round_time_ms': 0,
#    'data': {}},
#   {'type': 'death',
#    'time_ms': 99350,
#    'round': 2,
#    'round_time_ms': 22650,
#    'data': {'id': 'CHINO',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'SLACKED',
#      'pos': {'y': 383, 'x': 670},
#      'weapon': 'BAR',
#      'life': 8},
#     'pos': {'y': 498, 'x': 544},
#     'life': 12}},
#   {'type': 'death',
#    'time_ms': 105800,
#    'round': 2,
#    'round_time_ms': 29100,
#    'data': {'id': 'THEORY',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'JKAP',
#      'pos': {'y': 511, 'x': 684},
#      'weapon': 'STG-44',
#      'life': 13},
#     'pos': {'y': 518, 'x': 667},
#     'life': 11}},
#   {'type': 'death',
#    'time_ms': 107100,
#    'round': 2,
#    'round_time_ms': 30400,
#    'data': {'id': 'OCTANE',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'ACCURACY',
#      'pos': {'y': 72, 'x': 550},
#      'weapon': 'PPSh-41',
#      'life': 14},
#     'pos': {'y': 173, 'x': 588},
#     'life': 15}},
#   {'type': 'death',
#    'time_ms': 122200,
#    'round': 2,
#    'round_time_ms': 45500,
#    'data': {'id': 'SLACKED',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'KENNY',
#      'pos': {'y': 545, 'x': 537},
#      'weapon': 'BAR',
#      'life': 10},
#     'pos': {'y': 448, 'x': 585},
#     'life': 8}},
#   {'type': 'death',
#    'time_ms': 122850,
#    'round': 2,
#    'round_time_ms': 46150,
#    'data': {'id': 'JOHN',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'KENNY',
#      'pos': {'y': 545, 'x': 538},
#      'weapon': 'BAR',
#      'life': 10},
#     'pos': {'y': 489, 'x': 568},
#     'life': 9}},
#   {'type': 'death',
#    'time_ms': 125100,
#    'round': 2,
#    'round_time_ms': 48400,
#    'data': {'id': 'JKAP',
#     'attacker': {'means_of_death': 'head_shot',
#      'id': 'ACCURACY',
#      'pos': {'y': 335, 'x': 640},
#      'weapon': 'STG-44',
#      'life': 14},
#     'pos': {'y': 504, 'x': 665},
#     'life': 13}},
#   {'type': 'roundend',
#    'time_ms': 125200,
#    'round': 2,
#    'round_time_ms': 48500,
#    'data': {'score2': 0, 'score1': 2}},
#   {'type': 'spawn',
#    'time_ms': 141900,
#    'round': 2,
#    'round_time_ms': 65200,
#    'data': {'id': 'SLACKED', 'pos': {'y': 895, 'x': 515}, 'life': 16}},
#   {'type': 'spawn',
#    'time_ms': 141950,
#    'round': 2,
#    'round_time_ms': 65250,
#    'data': {'id': 'JOHN', 'pos': {'y': 895, 'x': 488}, 'life': 17}},
#   {'type': 'spawn',
#    'time_ms': 142000,
#    'round': 2,
#    'round_time_ms': 65300,
#    'data': {'id': 'KENNY', 'pos': {'y': 44, 'x': 428}, 'life': 18}},
#   {'type': 'spawn',
#    'time_ms': 142050,
#    'round': 2,
#    'round_time_ms': 65350,
#    'data': {'id': 'THEORY', 'pos': {'y': 33, 'x': 434}, 'life': 19}},
#   {'type': 'spawn',
#    'time_ms': 142100,
#    'round': 2,
#    'round_time_ms': 65400,
#    'data': {'id': 'CHINO', 'pos': {'y': 44, 'x': 456}, 'life': 20}},
#   {'type': 'spawn',
#    'time_ms': 142150,
#    'round': 2,
#    'round_time_ms': 65450,
#    'data': {'id': 'JKAP', 'pos': {'y': 895, 'x': 471}, 'life': 21}},
#   {'type': 'spawn',
#    'time_ms': 142250,
#    'round': 2,
#    'round_time_ms': 65550,
#    'data': {'id': 'OCTANE', 'pos': {'y': 895, 'x': 504}, 'life': 23}},
#   {'type': 'spawn',
#    'time_ms': 142300,
#    'round': 2,
#    'round_time_ms': 65600,
#    'data': {'id': 'ACCURACY', 'pos': {'y': 38, 'x': 445}, 'life': 22}},
#   {'type': 'roundstart',
#    'time_ms': 146750,
#    'round': 3,
#    'round_time_ms': 0,
#    'data': {}},
#   {'type': 'death',
#    'time_ms': 161850,
#    'round': 3,
#    'round_time_ms': 15100,
#    'data': {'id': 'THEORY',
#     'attacker': {'means_of_death': 'grenade_splash',
#      'id': 'SLACKED',
#      'pos': {'y': 587, 'x': 489},
#      'weapon': 'Stielhandgranate',
#      'life': 16},
#     'pos': {'y': 422, 'x': 653},
#     'life': 19}},
#   {'type': 'death',
#    'time_ms': 193950,
#    'round': 3,
#    'round_time_ms': 47200,
#    'data': {'id': 'ACCURACY',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'JKAP',
#      'pos': {'y': 363, 'x': 638},
#      'weapon': 'STG-44',
#      'life': 21},
#     'pos': {'y': 499, 'x': 659},
#     'life': 22}},
#   {'type': 'death',
#    'time_ms': 197550,
#    'round': 3,
#    'round_time_ms': 50800,
#    'data': {'id': 'OCTANE',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'KENNY',
#      'pos': {'y': 499, 'x': 666},
#      'weapon': 'BAR',
#      'life': 18},
#     'pos': {'y': 319, 'x': 641},
#     'life': 23}},
#   {'type': 'death',
#    'time_ms': 198150,
#    'round': 3,
#    'round_time_ms': 51400,
#    'data': {'id': 'KENNY',
#     'attacker': {'means_of_death': 'head_shot',
#      'id': 'JKAP',
#      'pos': {'y': 374, 'x': 638},
#      'weapon': 'STG-44',
#      'life': 21},
#     'pos': {'y': 500, 'x': 662},
#     'life': 18}},
#   {'type': 'death',
#    'time_ms': 199400,
#    'round': 3,
#    'round_time_ms': 52650,
#    'data': {'id': 'CHINO',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'SLACKED',
#      'pos': {'y': 496, 'x': 544},
#      'weapon': 'PPSh-41',
#      'life': 16},
#     'pos': {'y': 448, 'x': 602},
#     'life': 20}},
#   {'type': 'roundend',
#    'time_ms': 212400,
#    'round': 3,
#    'round_time_ms': 65650,
#    'data': {'score2': 1, 'score1': 2}},
#   {'type': 'spawn',
#    'time_ms': 222100,
#    'round': 3,
#    'round_time_ms': 75350,
#    'data': {'id': 'SLACKED', 'pos': {'y': 44, 'x': 428}, 'life': 24}},
#   {'type': 'spawn',
#    'time_ms': 222150,
#    'round': 3,
#    'round_time_ms': 75400,
#    'data': {'id': 'JOHN', 'pos': {'y': 38, 'x': 445}, 'life': 25}},
#   {'type': 'spawn',
#    'time_ms': 222250,
#    'round': 3,
#    'round_time_ms': 75500,
#    'data': {'id': 'KENNY', 'pos': {'y': 895, 'x': 488}, 'life': 26}},
#   {'type': 'spawn',
#    'time_ms': 222250,
#    'round': 3,
#    'round_time_ms': 75500,
#    'data': {'id': 'THEORY', 'pos': {'y': 895, 'x': 515}, 'life': 27}},
#   {'type': 'spawn',
#    'time_ms': 222300,
#    'round': 3,
#    'round_time_ms': 75550,
#    'data': {'id': 'CHINO', 'pos': {'y': 895, 'x': 504}, 'life': 28}},
#   {'type': 'spawn',
#    'time_ms': 222350,
#    'round': 3,
#    'round_time_ms': 75600,
#    'data': {'id': 'JKAP', 'pos': {'y': 33, 'x': 434}, 'life': 29}},
#   {'type': 'spawn',
#    'time_ms': 222400,
#    'round': 3,
#    'round_time_ms': 75650,
#    'data': {'id': 'ACCURACY', 'pos': {'y': 895, 'x': 471}, 'life': 30}},
#   {'type': 'spawn',
#    'time_ms': 222450,
#    'round': 3,
#    'round_time_ms': 75700,
#    'data': {'id': 'OCTANE', 'pos': {'y': 44, 'x': 456}, 'life': 31}},
#   {'type': 'roundstart',
#    'time_ms': 226950,
#    'round': 4,
#    'round_time_ms': 0,
#    'data': {}},
#   {'type': 'death',
#    'time_ms': 250100,
#    'round': 4,
#    'round_time_ms': 23150,
#    'data': {'id': 'CHINO',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'SLACKED',
#      'pos': {'y': 432, 'x': 597},
#      'weapon': 'BAR',
#      'life': 24},
#     'pos': {'y': 538, 'x': 539},
#     'life': 28}},
#   {'type': 'death',
#    'time_ms': 255050,
#    'round': 4,
#    'round_time_ms': 28100,
#    'data': {'id': 'JKAP',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'THEORY',
#      'pos': {'y': 518, 'x': 664},
#      'weapon': 'PPSh-41',
#      'life': 27},
#     'pos': {'y': 509, 'x': 677},
#     'life': 29}},
#   {'type': 'death',
#    'time_ms': 257850,
#    'round': 4,
#    'round_time_ms': 30900,
#    'data': {'id': 'THEORY',
#     'attacker': {'means_of_death': 'head_shot',
#      'id': 'SLACKED',
#      'pos': {'y': 416, 'x': 612},
#      'weapon': 'BAR',
#      'life': 24},
#     'pos': {'y': 491, 'x': 672},
#     'life': 27}},
#   {'type': 'death',
#    'time_ms': 260250,
#    'round': 4,
#    'round_time_ms': 33300,
#    'data': {'id': 'KENNY',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'SLACKED',
#      'pos': {'y': 378, 'x': 652},
#      'weapon': 'Machine Pistol',
#      'life': 24},
#     'pos': {'y': 371, 'x': 595},
#     'life': 26}},
#   {'type': 'death',
#    'time_ms': 266050,
#    'round': 4,
#    'round_time_ms': 39100,
#    'data': {'id': 'OCTANE',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'ACCURACY',
#      'pos': {'y': 299, 'x': 620},
#      'weapon': 'PPSh-41',
#      'life': 30},
#     'pos': {'y': 338, 'x': 636},
#     'life': 31}},
#   {'type': 'death',
#    'time_ms': 266550,
#    'round': 4,
#    'round_time_ms': 39600,
#    'data': {'id': 'JOHN',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'ACCURACY',
#      'pos': {'y': 307, 'x': 621},
#      'weapon': 'PPSh-41',
#      'life': 30},
#     'pos': {'y': 408, 'x': 658},
#     'life': 25}},
#   {'type': 'death',
#    'time_ms': 266900,
#    'round': 4,
#    'round_time_ms': 39950,
#    'data': {'id': 'SLACKED',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'ACCURACY',
#      'pos': {'y': 304, 'x': 620},
#      'weapon': 'PPSh-41',
#      'life': 30},
#     'pos': {'y': 447, 'x': 668},
#     'life': 24}},
#   {'type': 'roundend',
#    'time_ms': 267000,
#    'round': 4,
#    'round_time_ms': 40050,
#    'data': {'score2': 1, 'score1': 3}},
#   {'type': 'spawn',
#    'time_ms': 283700,
#    'round': 4,
#    'round_time_ms': 56750,
#    'data': {'id': 'SLACKED', 'pos': {'y': 895, 'x': 488}, 'life': 32}},
#   {'type': 'spawn',
#    'time_ms': 283750,
#    'round': 4,
#    'round_time_ms': 56800,
#    'data': {'id': 'JOHN', 'pos': {'y': 895, 'x': 504}, 'life': 33}},
#   {'type': 'spawn',
#    'time_ms': 283800,
#    'round': 4,
#    'round_time_ms': 56850,
#    'data': {'id': 'KENNY', 'pos': {'y': 33, 'x': 434}, 'life': 34}},
#   {'type': 'spawn',
#    'time_ms': 283900,
#    'round': 4,
#    'round_time_ms': 56950,
#    'data': {'id': 'CHINO', 'pos': {'y': 38, 'x': 445}, 'life': 36}},
#   {'type': 'spawn',
#    'time_ms': 283950,
#    'round': 4,
#    'round_time_ms': 57000,
#    'data': {'id': 'JKAP', 'pos': {'y': 895, 'x': 515}, 'life': 37}},
#   {'type': 'spawn',
#    'time_ms': 284000,
#    'round': 4,
#    'round_time_ms': 57050,
#    'data': {'id': 'ACCURACY', 'pos': {'y': 44, 'x': 456}, 'life': 38}},
#   {'type': 'spawn',
#    'time_ms': 284050,
#    'round': 4,
#    'round_time_ms': 57100,
#    'data': {'id': 'OCTANE', 'pos': {'y': 895, 'x': 471}, 'life': 39}},
#   {'type': 'spawn',
#    'time_ms': 284300,
#    'round': 4,
#    'round_time_ms': 57350,
#    'data': {'id': 'THEORY', 'pos': {'y': 44, 'x': 428}, 'life': 35}},
#   {'type': 'roundstart',
#    'time_ms': 288550,
#    'round': 5,
#    'round_time_ms': 0,
#    'data': {}},
#   {'type': 'death',
#    'time_ms': 315000,
#    'round': 5,
#    'round_time_ms': 26450,
#    'data': {'id': 'JKAP',
#     'attacker': {'means_of_death': 'head_shot',
#      'id': 'CHINO',
#      'pos': {'y': 515, 'x': 571},
#      'weapon': 'BAR',
#      'life': 36},
#     'pos': {'y': 549, 'x': 682},
#     'life': 37}},
#   {'type': 'death',
#    'time_ms': 318950,
#    'round': 5,
#    'round_time_ms': 30400,
#    'data': {'id': 'OCTANE',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'CHINO',
#      'pos': {'y': 512, 'x': 573},
#      'weapon': 'BAR',
#      'life': 36},
#     'pos': {'y': 567, 'x': 682},
#     'life': 39}},
#   {'type': 'death',
#    'time_ms': 322350,
#    'round': 5,
#    'round_time_ms': 33800,
#    'data': {'id': 'JOHN',
#     'attacker': {'means_of_death': 'head_shot',
#      'id': 'THEORY',
#      'pos': {'y': 506, 'x': 665},
#      'weapon': 'PPSh-41',
#      'life': 35},
#     'pos': {'y': 486, 'x': 544},
#     'life': 33}},
#   {'type': 'death',
#    'time_ms': 334000,
#    'round': 5,
#    'round_time_ms': 45450,
#    'data': {'id': 'SLACKED',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'CHINO',
#      'pos': {'y': 578, 'x': 490},
#      'weapon': 'BAR',
#      'life': 36},
#     'pos': {'y': 497, 'x': 465},
#     'life': 32}},
#   {'type': 'roundend',
#    'time_ms': 334100,
#    'round': 5,
#    'round_time_ms': 45550,
#    'data': {'score2': 1, 'score1': 4}},
#   {'type': 'spawn',
#    'time_ms': 350800,
#    'round': 5,
#    'round_time_ms': 62250,
#    'data': {'id': 'SLACKED', 'pos': {'y': 33, 'x': 434}, 'life': 40}},
#   {'type': 'spawn',
#    'time_ms': 350850,
#    'round': 5,
#    'round_time_ms': 62300,
#    'data': {'id': 'JOHN', 'pos': {'y': 44, 'x': 456}, 'life': 41}},
#   {'type': 'spawn',
#    'time_ms': 350900,
#    'round': 5,
#    'round_time_ms': 62350,
#    'data': {'id': 'KENNY', 'pos': {'y': 895, 'x': 471}, 'life': 42}},
#   {'type': 'spawn',
#    'time_ms': 351050,
#    'round': 5,
#    'round_time_ms': 62500,
#    'data': {'id': 'JKAP', 'pos': {'y': 38, 'x': 445}, 'life': 45}},
#   {'type': 'spawn',
#    'time_ms': 351100,
#    'round': 5,
#    'round_time_ms': 62550,
#    'data': {'id': 'THEORY', 'pos': {'y': 895, 'x': 504}, 'life': 43}},
#   {'type': 'spawn',
#    'time_ms': 351100,
#    'round': 5,
#    'round_time_ms': 62550,
#    'data': {'id': 'CHINO', 'pos': {'y': 895, 'x': 515}, 'life': 44}},
#   {'type': 'spawn',
#    'time_ms': 351100,
#    'round': 5,
#    'round_time_ms': 62550,
#    'data': {'id': 'ACCURACY', 'pos': {'y': 895, 'x': 488}, 'life': 46}},
#   {'type': 'spawn',
#    'time_ms': 351150,
#    'round': 5,
#    'round_time_ms': 62600,
#    'data': {'id': 'OCTANE', 'pos': {'y': 44, 'x': 428}, 'life': 47}},
#   {'type': 'roundstart',
#    'time_ms': 355650,
#    'round': 6,
#    'round_time_ms': 0,
#    'data': {}},
#   {'type': 'death',
#    'time_ms': 375900,
#    'round': 6,
#    'round_time_ms': 20250,
#    'data': {'id': 'ACCURACY',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'JOHN',
#      'pos': {'y': 458, 'x': 626},
#      'weapon': 'PPSh-41',
#      'life': 41},
#     'pos': {'y': 589, 'x': 673},
#     'life': 46}},
#   {'type': 'death',
#    'time_ms': 379950,
#    'round': 6,
#    'round_time_ms': 24300,
#    'data': {'id': 'KENNY',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'SLACKED',
#      'pos': {'y': 461, 'x': 623},
#      'weapon': 'BAR',
#      'life': 40},
#     'pos': {'y': 494, 'x': 544},
#     'life': 42}},
#   {'type': 'death',
#    'time_ms': 380300,
#    'round': 6,
#    'round_time_ms': 24650,
#    'data': {'id': 'THEORY',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'JOHN',
#      'pos': {'y': 516, 'x': 570},
#      'weapon': 'PPSh-41',
#      'life': 41},
#     'pos': {'y': 544, 'x': 676},
#     'life': 43}},
#   {'type': 'death',
#    'time_ms': 402450,
#    'round': 6,
#    'round_time_ms': 46800,
#    'data': {'id': 'CHINO',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'JKAP',
#      'pos': {'y': 460, 'x': 632},
#      'weapon': 'STG-44',
#      'life': 45},
#     'pos': {'y': 642, 'x': 689},
#     'life': 44}},
#   {'type': 'roundend',
#    'time_ms': 402550,
#    'round': 6,
#    'round_time_ms': 46900,
#    'data': {'score2': 2, 'score1': 4}},
#   {'type': 'spawn',
#    'time_ms': 419250,
#    'round': 6,
#    'round_time_ms': 63600,
#    'data': {'id': 'SLACKED', 'pos': {'y': 895, 'x': 471}, 'life': 48}},
#   {'type': 'spawn',
#    'time_ms': 419300,
#    'round': 6,
#    'round_time_ms': 63650,
#    'data': {'id': 'JOHN', 'pos': {'y': 895, 'x': 488}, 'life': 49}},
#   {'type': 'spawn',
#    'time_ms': 419350,
#    'round': 6,
#    'round_time_ms': 63700,
#    'data': {'id': 'KENNY', 'pos': {'y': 44, 'x': 428}, 'life': 50}},
#   {'type': 'spawn',
#    'time_ms': 419400,
#    'round': 6,
#    'round_time_ms': 63750,
#    'data': {'id': 'THEORY', 'pos': {'y': 44, 'x': 456}, 'life': 51}},
#   {'type': 'spawn',
#    'time_ms': 419450,
#    'round': 6,
#    'round_time_ms': 63800,
#    'data': {'id': 'CHINO', 'pos': {'y': 33, 'x': 434}, 'life': 52}},
#   {'type': 'spawn',
#    'time_ms': 419500,
#    'round': 6,
#    'round_time_ms': 63850,
#    'data': {'id': 'JKAP', 'pos': {'y': 895, 'x': 515}, 'life': 53}},
#   {'type': 'spawn',
#    'time_ms': 419550,
#    'round': 6,
#    'round_time_ms': 63900,
#    'data': {'id': 'ACCURACY', 'pos': {'y': 38, 'x': 445}, 'life': 54}},
#   {'type': 'spawn',
#    'time_ms': 419600,
#    'round': 6,
#    'round_time_ms': 63950,
#    'data': {'id': 'OCTANE', 'pos': {'y': 895, 'x': 504}, 'life': 55}},
#   {'type': 'roundstart',
#    'time_ms': 424100,
#    'round': 7,
#    'round_time_ms': 0,
#    'data': {}},
#   {'type': 'death',
#    'time_ms': 454800,
#    'round': 7,
#    'round_time_ms': 30700,
#    'data': {'id': 'ACCURACY',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'JKAP',
#      'pos': {'y': 314, 'x': 539},
#      'weapon': 'STG-44',
#      'life': 53},
#     'pos': {'y': 381, 'x': 566},
#     'life': 54}},
#   {'type': 'death',
#    'time_ms': 455250,
#    'round': 7,
#    'round_time_ms': 31150,
#    'data': {'id': 'JKAP',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'KENNY',
#      'pos': {'y': 252, 'x': 589},
#      'weapon': 'BAR',
#      'life': 50},
#     'pos': {'y': 317, 'x': 530},
#     'life': 53}},
#   {'type': 'death',
#    'time_ms': 462450,
#    'round': 7,
#    'round_time_ms': 38350,
#    'data': {'id': 'OCTANE',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'KENNY',
#      'pos': {'y': 326, 'x': 652},
#      'weapon': 'BAR',
#      'life': 50},
#     'pos': {'y': 383, 'x': 622},
#     'life': 55}},
#   {'type': 'death',
#    'time_ms': 465950,
#    'round': 7,
#    'round_time_ms': 41850,
#    'data': {'id': 'KENNY',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'JOHN',
#      'pos': {'y': 299, 'x': 628},
#      'weapon': 'PPSh-41',
#      'life': 49},
#     'pos': {'y': 372, 'x': 628},
#     'life': 50}},
#   {'type': 'death',
#    'time_ms': 468350,
#    'round': 7,
#    'round_time_ms': 44250,
#    'data': {'id': 'CHINO',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'SLACKED',
#      'pos': {'y': 528, 'x': 551},
#      'weapon': 'PPSh-41',
#      'life': 48},
#     'pos': {'y': 456, 'x': 590},
#     'life': 52}},
#   {'type': 'death',
#    'time_ms': 473100,
#    'round': 7,
#    'round_time_ms': 49000,
#    'data': {'id': 'THEORY',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'JOHN',
#      'pos': {'y': 467, 'x': 677},
#      'weapon': 'PPSh-41',
#      'life': 49},
#     'pos': {'y': 506, 'x': 629},
#     'life': 51}},
#   {'type': 'roundend',
#    'time_ms': 484000,
#    'round': 7,
#    'round_time_ms': 59900,
#    'data': {'score2': 3, 'score1': 4}},
#   {'type': 'spawn',
#    'time_ms': 493700,
#    'round': 7,
#    'round_time_ms': 69600,
#    'data': {'id': 'SLACKED', 'pos': {'y': 33, 'x': 434}, 'life': 56}},
#   {'type': 'spawn',
#    'time_ms': 493750,
#    'round': 7,
#    'round_time_ms': 69650,
#    'data': {'id': 'JOHN', 'pos': {'y': 44, 'x': 428}, 'life': 57}},
#   {'type': 'spawn',
#    'time_ms': 493800,
#    'round': 7,
#    'round_time_ms': 69700,
#    'data': {'id': 'KENNY', 'pos': {'y': 895, 'x': 504}, 'life': 58}},
#   {'type': 'spawn',
#    'time_ms': 493900,
#    'round': 7,
#    'round_time_ms': 69800,
#    'data': {'id': 'CHINO', 'pos': {'y': 895, 'x': 471}, 'life': 60}},
#   {'type': 'spawn',
#    'time_ms': 493950,
#    'round': 7,
#    'round_time_ms': 69850,
#    'data': {'id': 'JKAP', 'pos': {'y': 44, 'x': 456}, 'life': 61}},
#   {'type': 'spawn',
#    'time_ms': 494000,
#    'round': 7,
#    'round_time_ms': 69900,
#    'data': {'id': 'THEORY', 'pos': {'y': 895, 'x': 488}, 'life': 59}},
#   {'type': 'spawn',
#    'time_ms': 494000,
#    'round': 7,
#    'round_time_ms': 69900,
#    'data': {'id': 'ACCURACY', 'pos': {'y': 895, 'x': 515}, 'life': 62}},
#   {'type': 'spawn',
#    'time_ms': 494050,
#    'round': 7,
#    'round_time_ms': 69950,
#    'data': {'id': 'OCTANE', 'pos': {'y': 38, 'x': 445}, 'life': 63}},
#   {'type': 'roundstart',
#    'time_ms': 498550,
#    'round': 8,
#    'round_time_ms': 0,
#    'data': {}},
#   {'type': 'death',
#    'time_ms': 518050,
#    'round': 8,
#    'round_time_ms': 19500,
#    'data': {'id': 'THEORY',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'OCTANE',
#      'pos': {'y': 383, 'x': 657},
#      'weapon': 'STG-44',
#      'life': 63},
#     'pos': {'y': 493, 'x': 678},
#     'life': 59}},
#   {'type': 'death',
#    'time_ms': 520950,
#    'round': 8,
#    'round_time_ms': 22400,
#    'data': {'id': 'SLACKED',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'KENNY',
#      'pos': {'y': 497, 'x': 544},
#      'weapon': 'BAR',
#      'life': 58},
#     'pos': {'y': 461, 'x': 626},
#     'life': 56}},
#   {'type': 'death',
#    'time_ms': 521200,
#    'round': 8,
#    'round_time_ms': 22650,
#    'data': {'id': 'KENNY',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'OCTANE',
#      'pos': {'y': 407, 'x': 653},
#      'weapon': 'STG-44',
#      'life': 63},
#     'pos': {'y': 500, 'x': 544},
#     'life': 58}},
#   {'type': 'death',
#    'time_ms': 521600,
#    'round': 8,
#    'round_time_ms': 23050,
#    'data': {'id': 'OCTANE',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'CHINO',
#      'pos': {'y': 503, 'x': 585},
#      'weapon': 'BAR',
#      'life': 60},
#     'pos': {'y': 410, 'x': 654},
#     'life': 63}},
#   {'type': 'death',
#    'time_ms': 526850,
#    'round': 8,
#    'round_time_ms': 28300,
#    'data': {'id': 'JOHN',
#     'attacker': {'means_of_death': 'head_shot',
#      'id': 'ACCURACY',
#      'pos': {'y': 511, 'x': 669},
#      'weapon': 'BAR',
#      'life': 62},
#     'pos': {'y': 486, 'x': 669},
#     'life': 57}},
#   {'type': 'death',
#    'time_ms': 534550,
#    'round': 8,
#    'round_time_ms': 36000,
#    'data': {'id': 'CHINO',
#     'attacker': {'means_of_death': 'head_shot',
#      'id': 'JKAP',
#      'pos': {'y': 333, 'x': 628},
#      'weapon': 'STG-44',
#      'life': 61},
#     'pos': {'y': 493, 'x': 669},
#     'life': 60}},
#   {'type': 'death',
#    'time_ms': 551200,
#    'round': 8,
#    'round_time_ms': 52650,
#    'data': {'id': 'JKAP',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'ACCURACY',
#      'pos': {'y': 462, 'x': 676},
#      'weapon': 'BAR',
#      'life': 62},
#     'pos': {'y': 338, 'x': 624},
#     'life': 61}},
#   {'type': 'roundend',
#    'time_ms': 561550,
#    'round': 8,
#    'round_time_ms': 63000,
#    'data': {'score2': 3, 'score1': 5}},
#   {'type': 'spawn',
#    'time_ms': 571250,
#    'round': 8,
#    'round_time_ms': 72700,
#    'data': {'id': 'SLACKED', 'pos': {'y': 895, 'x': 488}, 'life': 64}},
#   {'type': 'spawn',
#    'time_ms': 571300,
#    'round': 8,
#    'round_time_ms': 72750,
#    'data': {'id': 'JOHN', 'pos': {'y': 895, 'x': 504}, 'life': 65}},
#   {'type': 'spawn',
#    'time_ms': 571350,
#    'round': 8,
#    'round_time_ms': 72800,
#    'data': {'id': 'KENNY', 'pos': {'y': 44, 'x': 456}, 'life': 66}},
#   {'type': 'spawn',
#    'time_ms': 571450,
#    'round': 8,
#    'round_time_ms': 72900,
#    'data': {'id': 'CHINO', 'pos': {'y': 33, 'x': 434}, 'life': 68}},
#   {'type': 'spawn',
#    'time_ms': 571550,
#    'round': 8,
#    'round_time_ms': 73000,
#    'data': {'id': 'THEORY', 'pos': {'y': 44, 'x': 428}, 'life': 67}},
#   {'type': 'spawn',
#    'time_ms': 571600,
#    'round': 8,
#    'round_time_ms': 73050,
#    'data': {'id': 'JKAP', 'pos': {'y': 895, 'x': 471}, 'life': 69}},
#   {'type': 'spawn',
#    'time_ms': 571650,
#    'round': 8,
#    'round_time_ms': 73100,
#    'data': {'id': 'ACCURACY', 'pos': {'y': 38, 'x': 445}, 'life': 70}},
#   {'type': 'spawn',
#    'time_ms': 571750,
#    'round': 8,
#    'round_time_ms': 73200,
#    'data': {'id': 'OCTANE', 'pos': {'y': 895, 'x': 515}, 'life': 71}},
#   {'type': 'roundstart',
#    'time_ms': 576100,
#    'round': 9,
#    'round_time_ms': 0,
#    'data': {}},
#   {'type': 'death',
#    'time_ms': 601850,
#    'round': 9,
#    'round_time_ms': 25750,
#    'data': {'id': 'THEORY',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'JKAP',
#      'pos': {'y': 643, 'x': 668},
#      'weapon': 'STG-44',
#      'life': 69},
#     'pos': {'y': 539, 'x': 671},
#     'life': 67}},
#   {'type': 'death',
#    'time_ms': 619850,
#    'round': 9,
#    'round_time_ms': 43750,
#    'data': {'id': 'JKAP',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'CHINO',
#      'pos': {'y': 319, 'x': 637},
#      'weapon': 'BAR',
#      'life': 68},
#     'pos': {'y': 560, 'x': 649},
#     'life': 69}},
#   {'type': 'death',
#    'time_ms': 623950,
#    'round': 9,
#    'round_time_ms': 47850,
#    'data': {'id': 'ACCURACY',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'JOHN',
#      'pos': {'y': 434, 'x': 655},
#      'weapon': 'PPSh-41',
#      'life': 65},
#     'pos': {'y': 369, 'x': 657},
#     'life': 70}},
#   {'type': 'death',
#    'time_ms': 624150,
#    'round': 9,
#    'round_time_ms': 48050,
#    'data': {'id': 'OCTANE',
#     'attacker': {'means_of_death': 'pistol_bullet',
#      'id': 'KENNY',
#      'pos': {'y': 330, 'x': 506},
#      'weapon': 'PPSh-41',
#      'life': 66},
#     'pos': {'y': 388, 'x': 392},
#     'life': 71}},
#   {'type': 'death',
#    'time_ms': 624550,
#    'round': 9,
#    'round_time_ms': 48450,
#    'data': {'id': 'JOHN',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'CHINO',
#      'pos': {'y': 362, 'x': 640},
#      'weapon': 'BAR',
#      'life': 68},
#     'pos': {'y': 433, 'x': 639},
#     'life': 65}},
#   {'type': 'death',
#    'time_ms': 627500,
#    'round': 9,
#    'round_time_ms': 51400,
#    'data': {'id': 'SLACKED',
#     'attacker': {'means_of_death': 'rifle_bullet',
#      'id': 'CHINO',
#      'pos': {'y': 458, 'x': 630},
#      'weapon': 'BAR',
#      'life': 68},
#     'pos': {'y': 497, 'x': 663},
#     'life': 64}},
#   {'type': 'roundend',
#    'time_ms': 627600,
#    'round': 9,
#    'round_time_ms': 51500,
#    'data': {'score2': 3, 'score1': 6}}]}

# %% [markdown]
# You have no seen this yet, but dicts and lists can be *nested*.  Here is a simple dict:

# %%
simpledict = {"a": 1, "b": 2}

# %% [markdown]
# There is no reason why the values can't themselves be dicts and lists:

# %%
nesteddict = {"a": [5, 6, 7], "b": {"dogs": 10, "cats": 11}}

# %% [markdown]
# This nesting can be arbitrarily gnarly.  Let's have a look at our deserialized json (which is now a dict):

# %%
data.keys()
# Out:
# dict_keys(['title', 'platform', 'id', 'series_id', 'start_time_s', 'end_time_s', 'duration_ms', 'mode', 'map', 'rounds', 'teams', 'players', 'events'])

# %%
data['title']
# Out:
# 'ww2'

# %%
data['platform']
# Out:
# 'ps4'

# %%
# timestamps are OFTEN stored as "UNIX timestamps".
# This is the number of seconds elapsed since January 1, 1970
data['start_time_s']
# Out:
# 1515984053

# %%
data['end_time_s']
# Out:
# 1515984523

# %%
data['end_time_s'] - data['start_time_s']
# Out:
# 470

# %%
data['duration_ms']
# Out:
# 470000

# %%
data['mode']
# Out:
# 'Search & Destroy'

# %%
data['map']
# Out:
# 'Sainte Marie du Mont'

# %%
data['rounds']
# Out:
# 9

# %%
data['teams']
# Out:
# [{'name': 'TEAM KALIBER',
#   'score': 6,
#   'is_victor': True,
#   'round_scores': [1, 1, 0, 1, 1, 0, 0, 1, 1],
#   'side': 'home'},
#  {'name': 'LUMINOSITY GAMING',
#   'score': 3,
#   'is_victor': False,
#   'round_scores': [0, 0, 1, 0, 0, 1, 1, 0, 0],
#   'side': 'away'}]

# %%
data['teams'][0]
# Out:
# {'name': 'TEAM KALIBER',
#  'score': 6,
#  'is_victor': True,
#  'round_scores': [1, 1, 0, 1, 1, 0, 0, 1, 1],
#  'side': 'home'}

# %%
data['teams'][0]['name']
# Out:
# 'TEAM KALIBER'

# %%
data['players']
# Out:
# [{'name': 'ACCURACY',
#   'team': 'TEAM KALIBER',
#   'kills': 8,
#   'deaths': 4,
#   'kd': 2.0,
#   'kills_per_10min': 10.2,
#   'deaths_per_10min': 5.1,
#   'assists': 8,
#   'headshots': 2,
#   'suicides': 0,
#   'team_kills': 0,
#   'team_deaths': 0,
#   'stayed_alive_kills': 8,
#   'hits': 53,
#   'shots': 195,
#   'accuracy': 27.2,
#   'num_lives': 9,
#   'time_alive_s': 398.2,
#   'avg_time_per_life_s': 44.2,
#   'fave_weapon': 'BAR',
#   'fave_division': 'Armored',
#   'fave_training': 'Scoped',
#   'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#   '2piece': 0,
#   '3piece': 1,
#   '4piece': 0,
#   '4streak': 0,
#   '5streak': 0,
#   '6streak': 0,
#   '7streak': 0,
#   '8+streak': 0,
#   'scorestreaks_earned': 0,
#   'scorestreaks_used': 0,
#   'scorestreaks_deployed': 0,
#   'scorestreaks_kills': 0,
#   'scorestreaks_assists': 0,
#   'snd_firstbloods': 0,
#   'snd_pickups': 1,
#   'snd_plants': 1,
#   'snd_defuses': 1,
#   'snd_sneak_defuses': 0,
#   'snd_rounds': 9,
#   'snd_firstdeaths': 2,
#   'snd_survives': 5,
#   'snd_1kill_round': 1,
#   'snd_2kill_round': 2,
#   'snd_3kill_round': 1,
#   'snd_4kill_round': 0},
#  {'name': 'CHINO',
#   'team': 'TEAM KALIBER',
#   'kills': 8,
#   'deaths': 7,
#   'kd': 1.1400000000000001,
#   'kills_per_10min': 10.2,
#   'deaths_per_10min': 8.9,
#   'assists': 1,
#   'headshots': 1,
#   'suicides': 0,
#   'team_kills': 0,
#   'team_deaths': 0,
#   'stayed_alive_kills': 8,
#   'hits': 28,
#   'shots': 128,
#   'accuracy': 21.9,
#   'num_lives': 9,
#   'time_alive_s': 368.4,
#   'avg_time_per_life_s': 40.9,
#   'fave_weapon': 'BAR',
#   'fave_division': 'Armored',
#   'fave_training': 'Scoped',
#   'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#   '2piece': 1,
#   '3piece': 1,
#   '4piece': 0,
#   '4streak': 0,
#   '5streak': 0,
#   '6streak': 0,
#   '7streak': 0,
#   '8+streak': 0,
#   'scorestreaks_earned': 0,
#   'scorestreaks_used': 0,
#   'scorestreaks_deployed': 0,
#   'scorestreaks_kills': 0,
#   'scorestreaks_assists': 0,
#   'snd_firstbloods': 2,
#   'snd_pickups': 0,
#   'snd_plants': 0,
#   'snd_defuses': 0,
#   'snd_sneak_defuses': 0,
#   'snd_rounds': 9,
#   'snd_firstdeaths': 2,
#   'snd_survives': 2,
#   'snd_1kill_round': 2,
#   'snd_2kill_round': 0,
#   'snd_3kill_round': 2,
#   'snd_4kill_round': 0},
#  {'name': 'KENNY',
#   'team': 'TEAM KALIBER',
#   'kills': 7,
#   'deaths': 5,
#   'kd': 1.4,
#   'kills_per_10min': 8.9,
#   'deaths_per_10min': 6.4,
#   'assists': 0,
#   'headshots': 0,
#   'suicides': 0,
#   'team_kills': 0,
#   'team_deaths': 0,
#   'stayed_alive_kills': 4,
#   'hits': 22,
#   'shots': 68,
#   'accuracy': 32.4,
#   'num_lives': 9,
#   'time_alive_s': 374.2,
#   'avg_time_per_life_s': 41.6,
#   'fave_weapon': 'BAR',
#   'fave_division': 'Armored',
#   'fave_training': 'Scoped',
#   'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#   '2piece': 1,
#   '3piece': 0,
#   '4piece': 0,
#   '4streak': 0,
#   '5streak': 0,
#   '6streak': 0,
#   '7streak': 0,
#   '8+streak': 0,
#   'scorestreaks_earned': 0,
#   'scorestreaks_used': 0,
#   'scorestreaks_deployed': 0,
#   'scorestreaks_kills': 0,
#   'scorestreaks_assists': 0,
#   'snd_firstbloods': 0,
#   'snd_pickups': 0,
#   'snd_plants': 0,
#   'snd_defuses': 0,
#   'snd_sneak_defuses': 0,
#   'snd_rounds': 9,
#   'snd_firstdeaths': 0,
#   'snd_survives': 4,
#   'snd_1kill_round': 3,
#   'snd_2kill_round': 2,
#   'snd_3kill_round': 0,
#   'snd_4kill_round': 0},
#  {'name': 'THEORY',
#   'team': 'TEAM KALIBER',
#   'kills': 4,
#   'deaths': 7,
#   'kd': 0.5700000000000001,
#   'kills_per_10min': 5.1,
#   'deaths_per_10min': 8.9,
#   'assists': 0,
#   'headshots': 2,
#   'suicides': 0,
#   'team_kills': 0,
#   'team_deaths': 0,
#   'stayed_alive_kills': 3,
#   'hits': 18,
#   'shots': 120,
#   'accuracy': 15.0,
#   'num_lives': 9,
#   'time_alive_s': 294.7,
#   'avg_time_per_life_s': 32.7,
#   'fave_weapon': 'PPSh-41',
#   'fave_division': 'Expeditionary',
#   'fave_training': 'Hunker',
#   'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#   '2piece': 0,
#   '3piece': 0,
#   '4piece': 0,
#   '4streak': 0,
#   '5streak': 0,
#   '6streak': 0,
#   '7streak': 0,
#   '8+streak': 0,
#   'scorestreaks_earned': 0,
#   'scorestreaks_used': 0,
#   'scorestreaks_deployed': 0,
#   'scorestreaks_kills': 0,
#   'scorestreaks_assists': 0,
#   'snd_firstbloods': 0,
#   'snd_pickups': 5,
#   'snd_plants': 4,
#   'snd_defuses': 0,
#   'snd_sneak_defuses': 0,
#   'snd_rounds': 9,
#   'snd_firstdeaths': 3,
#   'snd_survives': 2,
#   'snd_1kill_round': 2,
#   'snd_2kill_round': 1,
#   'snd_3kill_round': 0,
#   'snd_4kill_round': 0},
#  {'name': 'JKAP',
#   'team': 'LUMINOSITY GAMING',
#   'kills': 7,
#   'deaths': 7,
#   'kd': 1.0,
#   'kills_per_10min': 8.9,
#   'deaths_per_10min': 8.9,
#   'assists': 3,
#   'headshots': 2,
#   'suicides': 0,
#   'team_kills': 0,
#   'team_deaths': 0,
#   'stayed_alive_kills': 6,
#   'hits': 41,
#   'shots': 211,
#   'accuracy': 19.4,
#   'num_lives': 9,
#   'time_alive_s': 383.0,
#   'avg_time_per_life_s': 42.6,
#   'fave_weapon': 'STG-44',
#   'fave_division': 'Armored',
#   'fave_training': 'Scoped',
#   'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#   '2piece': 1,
#   '3piece': 0,
#   '4piece': 0,
#   '4streak': 0,
#   '5streak': 0,
#   '6streak': 0,
#   '7streak': 0,
#   '8+streak': 0,
#   'scorestreaks_earned': 0,
#   'scorestreaks_used': 0,
#   'scorestreaks_deployed': 0,
#   'scorestreaks_kills': 0,
#   'scorestreaks_assists': 0,
#   'snd_firstbloods': 2,
#   'snd_pickups': 3,
#   'snd_plants': 1,
#   'snd_defuses': 1,
#   'snd_sneak_defuses': 0,
#   'snd_rounds': 9,
#   'snd_firstdeaths': 1,
#   'snd_survives': 2,
#   'snd_1kill_round': 5,
#   'snd_2kill_round': 1,
#   'snd_3kill_round': 0,
#   'snd_4kill_round': 0},
#  {'name': 'JOHN',
#   'team': 'LUMINOSITY GAMING',
#   'kills': 5,
#   'deaths': 6,
#   'kd': 0.8300000000000001,
#   'kills_per_10min': 6.4,
#   'deaths_per_10min': 7.7,
#   'assists': 3,
#   'headshots': 0,
#   'suicides': 0,
#   'team_kills': 0,
#   'team_deaths': 0,
#   'stayed_alive_kills': 4,
#   'hits': 25,
#   'shots': 214,
#   'accuracy': 11.7,
#   'num_lives': 9,
#   'time_alive_s': 403.4,
#   'avg_time_per_life_s': 44.8,
#   'fave_weapon': 'PPSh-41',
#   'fave_division': 'Armored',
#   'fave_training': 'Inconspicuous',
#   'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Artillery Barrage'],
#   '2piece': 1,
#   '3piece': 0,
#   '4piece': 0,
#   '4streak': 0,
#   '5streak': 0,
#   '6streak': 0,
#   '7streak': 0,
#   '8+streak': 0,
#   'scorestreaks_earned': 2,
#   'scorestreaks_used': 2,
#   'scorestreaks_deployed': 2,
#   'scorestreaks_kills': 0,
#   'scorestreaks_assists': 0,
#   'snd_firstbloods': 1,
#   'snd_pickups': 1,
#   'snd_plants': 1,
#   'snd_defuses': 1,
#   'snd_sneak_defuses': 0,
#   'snd_rounds': 9,
#   'snd_firstdeaths': 1,
#   'snd_survives': 3,
#   'snd_1kill_round': 1,
#   'snd_2kill_round': 2,
#   'snd_3kill_round': 0,
#   'snd_4kill_round': 0},
#  {'name': 'OCTANE',
#   'team': 'LUMINOSITY GAMING',
#   'kills': 3,
#   'deaths': 8,
#   'kd': 0.38,
#   'kills_per_10min': 3.8,
#   'deaths_per_10min': 10.2,
#   'assists': 3,
#   'headshots': 1,
#   'suicides': 0,
#   'team_kills': 0,
#   'team_deaths': 0,
#   'stayed_alive_kills': 2,
#   'hits': 22,
#   'shots': 116,
#   'accuracy': 19.0,
#   'num_lives': 9,
#   'time_alive_s': 362.1,
#   'avg_time_per_life_s': 40.2,
#   'fave_weapon': 'STG-44',
#   'fave_division': 'Armored',
#   'fave_training': 'Scoped',
#   'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#   '2piece': 1,
#   '3piece': 0,
#   '4piece': 0,
#   '4streak': 0,
#   '5streak': 0,
#   '6streak': 0,
#   '7streak': 0,
#   '8+streak': 0,
#   'scorestreaks_earned': 0,
#   'scorestreaks_used': 0,
#   'scorestreaks_deployed': 0,
#   'scorestreaks_kills': 0,
#   'scorestreaks_assists': 0,
#   'snd_firstbloods': 1,
#   'snd_pickups': 0,
#   'snd_plants': 0,
#   'snd_defuses': 0,
#   'snd_sneak_defuses': 0,
#   'snd_rounds': 9,
#   'snd_firstdeaths': 0,
#   'snd_survives': 1,
#   'snd_1kill_round': 1,
#   'snd_2kill_round': 1,
#   'snd_3kill_round': 0,
#   'snd_4kill_round': 0},
#  {'name': 'SLACKED',
#   'team': 'LUMINOSITY GAMING',
#   'kills': 8,
#   'deaths': 6,
#   'kd': 1.33,
#   'kills_per_10min': 10.2,
#   'deaths_per_10min': 7.7,
#   'assists': 1,
#   'headshots': 1,
#   'suicides': 0,
#   'team_kills': 0,
#   'team_deaths': 0,
#   'stayed_alive_kills': 8,
#   'hits': 26,
#   'shots': 169,
#   'accuracy': 15.4,
#   'num_lives': 9,
#   'time_alive_s': 413.8,
#   'avg_time_per_life_s': 46.0,
#   'fave_weapon': 'PPSh-41',
#   'fave_division': 'Mountain',
#   'fave_training': 'Hunker',
#   'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#   '2piece': 1,
#   '3piece': 0,
#   '4piece': 0,
#   '4streak': 0,
#   '5streak': 0,
#   '6streak': 0,
#   '7streak': 0,
#   '8+streak': 0,
#   'scorestreaks_earned': 0,
#   'scorestreaks_used': 0,
#   'scorestreaks_deployed': 0,
#   'scorestreaks_kills': 0,
#   'scorestreaks_assists': 0,
#   'snd_firstbloods': 3,
#   'snd_pickups': 0,
#   'snd_plants': 0,
#   'snd_defuses': 0,
#   'snd_sneak_defuses': 0,
#   'snd_rounds': 9,
#   'snd_firstdeaths': 0,
#   'snd_survives': 3,
#   'snd_1kill_round': 3,
#   'snd_2kill_round': 1,
#   'snd_3kill_round': 1,
#   'snd_4kill_round': 0}]

# %%
data['players'][0]
# Out:
# {'name': 'ACCURACY',
#  'team': 'TEAM KALIBER',
#  'kills': 8,
#  'deaths': 4,
#  'kd': 2.0,
#  'kills_per_10min': 10.2,
#  'deaths_per_10min': 5.1,
#  'assists': 8,
#  'headshots': 2,
#  'suicides': 0,
#  'team_kills': 0,
#  'team_deaths': 0,
#  'stayed_alive_kills': 8,
#  'hits': 53,
#  'shots': 195,
#  'accuracy': 27.2,
#  'num_lives': 9,
#  'time_alive_s': 398.2,
#  'avg_time_per_life_s': 44.2,
#  'fave_weapon': 'BAR',
#  'fave_division': 'Armored',
#  'fave_training': 'Scoped',
#  'fave_scorestreaks': ['Fighter Pilot', 'Glide Bomb', 'Mortar Strike'],
#  '2piece': 0,
#  '3piece': 1,
#  '4piece': 0,
#  '4streak': 0,
#  '5streak': 0,
#  '6streak': 0,
#  '7streak': 0,
#  '8+streak': 0,
#  'scorestreaks_earned': 0,
#  'scorestreaks_used': 0,
#  'scorestreaks_deployed': 0,
#  'scorestreaks_kills': 0,
#  'scorestreaks_assists': 0,
#  'snd_firstbloods': 0,
#  'snd_pickups': 1,
#  'snd_plants': 1,
#  'snd_defuses': 1,
#  'snd_sneak_defuses': 0,
#  'snd_rounds': 9,
#  'snd_firstdeaths': 2,
#  'snd_survives': 5,
#  'snd_1kill_round': 1,
#  'snd_2kill_round': 2,
#  'snd_3kill_round': 1,
#  'snd_4kill_round': 0}
